# %% [markdown]
# # End-to-End Document Processing with Assessment
#
# This notebook demonstrates how to process a document using the modular Document-based approach with:
#
# 1. OCR Service - Convert a PDF document to text using AWS Textract
# 2. Classification Service - Classify document pages into sections using Bedrock
# 3. Extraction Service - Extract structured information from sections using Bedrock
# 4. **Assessment Service - Assess the confidence and accuracy of extraction results**
# 5. Evaluation Service - Evaluate accuracy of extracted information
#
# Each step uses the unified Document object model for data flow and consistency.
#
# > **Note**: This notebook uses AWS services including S3, Textract, and Bedrock. You need valid AWS credentials with appropriate permissions to run this notebook.

# %% [markdown]
# ## 1. Install Dependencies
#
# The IDP common package supports granular installation through extras. You can install:
# - `[core]` - Just core functionality
# - `[ocr]` - OCR service with Textract dependencies
# - `[classification]` - Classification service dependencies
# - `[extraction]` - Extraction service dependencies
# - `[evaluation]` - Evaluation service dependencies
# - `[all]` - All of the above

# %%
# Let's make sure that modules are autoreloaded
# %load_ext autoreload
# %autoreload 2

# First uninstall existing package (to ensure we get the latest version)
# %pip uninstall -y idp_common

# Install the IDP common package with all components in development mode
# %pip install -q -e "../lib/idp_common_pkg[dev, all]"

# Check installed version
# %pip show idp_common | grep -E "Version|Location"

# Optionally use a .env file for environment variables
try:
    from dotenv import load_dotenv
    load_dotenv()  
except ImportError:
    pass
# Out:
# Found existing installation: idp_common 0.3.2
# Uninstalling idp_common-0.3.2:
#   Successfully uninstalled idp_common-0.3.2
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Version: 0.3.2
# Location: /home/ec2-user/.local/lib/python3.11/site-packages
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 2. Import Libraries and Set Up Environment

# %%
import os
import json
import time
import boto3
import logging
import datetime

# Import base libraries
from idp_common.models import Document, Status, Section, Page
from idp_common import ocr, classification, extraction, assessment, evaluation

# Configure logging 
logging.basicConfig(level=logging.WARNING)  # Set root logger to WARNING (less verbose)
logging.getLogger('idp_common.ocr.service').setLevel(logging.INFO)  # Focus on service logs
logging.getLogger('textractor').setLevel(logging.WARNING)  # Suppress textractor logs
logging.getLogger('idp_common.evaluation.service').setLevel(logging.DEBUG)  # Enable evaluation logs
logging.getLogger('idp_common.assessment.service').setLevel(logging.DEBUG)  # Enable assessment logs
logging.getLogger('idp_common.bedrock.client').setLevel(logging.DEBUG)  # show prompts

# Set environment variables
os.environ['METRIC_NAMESPACE'] = 'IDP-Notebook-Assessment-Example'
os.environ['AWS_REGION'] = boto3.session.Session().region_name or 'us-east-1'

# Get AWS account ID for unique bucket names
sts_client = boto3.client('sts')
account_id = sts_client.get_caller_identity()["Account"]
region = os.environ['AWS_REGION']

# Define sample PDF path 
SAMPLE_PDF_PATH = "../samples/rvl_cdip_package.pdf"

# Create unique bucket names based on account ID and region
input_bucket_name =  os.getenv("IDP_INPUT_BUCKET_NAME", f"idp-notebook-assess-input-{account_id}-{region}")
output_bucket_name = os.getenv("IDP_OUTPUT_BUCKET_NAME", f"idp-notebook-assess-output-{account_id}-{region}")

print("Environment setup:")
print(f"METRIC_NAMESPACE: {os.environ.get('METRIC_NAMESPACE')}")
print(f"AWS_REGION: {os.environ.get('AWS_REGION')}")
print(f"Input bucket: {input_bucket_name}")
print(f"Output bucket: {output_bucket_name}")
print(f"SAMPLE_PDF_PATH: {SAMPLE_PDF_PATH}")
# Out:
# Environment setup:
# METRIC_NAMESPACE: IDP-Notebook-Assessment-Example
# AWS_REGION: us-west-2
# Input bucket: idp-notebook-assess-input-912625584728-us-west-2
# Output bucket: idp-notebook-assess-output-912625584728-us-west-2
# SAMPLE_PDF_PATH: ../samples/rvl_cdip_package.pdf

# %% [markdown]
# ## 3. Set Up S3 Buckets and Upload Sample File

# %%
# Create S3 client
s3_client = boto3.client('s3')

# Helper function to parse S3 URIs
def parse_s3_uri(uri):
    parts = uri.replace("s3://", "").split("/")
    bucket = parts[0]
    key = "/".join(parts[1:])
    return bucket, key

# Helper function to load JSON from S3
def load_json_from_s3(uri):
    bucket, key = parse_s3_uri(uri)
    response = s3_client.get_object(Bucket=bucket, Key=key)
    content = response['Body'].read().decode('utf-8')
    return json.loads(content)

# Function to create a bucket if it doesn't exist
def ensure_bucket_exists(bucket_name):
    try:
        s3_client.head_bucket(Bucket=bucket_name)
        print(f"Bucket {bucket_name} already exists")
    except Exception:
        try:
            if region == 'us-east-1':
                s3_client.create_bucket(Bucket=bucket_name)
            else:
                s3_client.create_bucket(
                    Bucket=bucket_name,
                    CreateBucketConfiguration={'LocationConstraint': region}
                )
            print(f"Created bucket: {bucket_name}")
            
            # Wait for bucket to be accessible
            waiter = s3_client.get_waiter('bucket_exists')
            waiter.wait(Bucket=bucket_name)
        except Exception as e:
            print(f"Error creating bucket {bucket_name}: {str(e)}")
            raise

# Ensure both buckets exist
ensure_bucket_exists(input_bucket_name)
ensure_bucket_exists(output_bucket_name)

# Upload the sample file to S3
sample_file_key = "sample-assessment-" + datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S") + ".pdf"
with open(SAMPLE_PDF_PATH, 'rb') as file_data:
    s3_client.upload_fileobj(file_data, input_bucket_name, sample_file_key)

print(f"Uploaded sample file to: s3://{input_bucket_name}/{sample_file_key}")
# Out:
# Bucket idp-notebook-assess-input-912625584728-us-west-2 already exists
# Bucket idp-notebook-assess-output-912625584728-us-west-2 already exists
# Uploaded sample file to: s3://idp-notebook-assess-input-912625584728-us-west-2/sample-assessment-2025-06-06_20-51-46.pdf

# %% [markdown]
# ## 4. Set Up Configuration with Assessment

# %%
# Sample configuration that includes assessment section
CONFIG = {
    "assessment": {
        "model": "us.amazon.nova-pro-v1:0",
        "temperature": 0.0,
        "top_k": 5,
        "top_p": 0.1,
        "max_tokens": 4096,
        "system_prompt": "You are a document analysis assessment expert. Your task is to evaluate the confidence and accuracy of extraction results by analyzing the source document evidence. Respond only with JSON containing confidence scores and reasoning for each extracted attribute.",
        "task_prompt": """<background>
You are an expert document analysis assessment system. Your task is to evaluate the confidence and accuracy of extraction results for a document of class {DOCUMENT_CLASS}.
</background>

<task>
Analyze the extraction results against the source document and provide confidence assessments for each extracted attribute. Consider factors such as:
1. Text clarity and OCR quality in the source regions
2. Alignment between extracted values and document content
3. Presence of clear evidence supporting the extraction
4. Potential ambiguity or uncertainty in the source material
5. Completeness and accuracy of the extracted information
</task>

<assessment-guidelines>
For each attribute, provide:
1. A confidence score between 0.0 and 1.0 where:
   - 1.0 = Very high confidence, clear and unambiguous evidence
   - 0.8-0.9 = High confidence, strong evidence with minor uncertainty
   - 0.6-0.7 = Medium confidence, reasonable evidence but some ambiguity
   - 0.4-0.5 = Low confidence, weak or unclear evidence
   - 0.0-0.3 = Very low confidence, little to no supporting evidence

2. A clear reason explaining the confidence score, including:
   - What evidence supports or contradicts the extraction
   - Any OCR quality issues that affect confidence
   - Clarity of the source document in relevant areas
   - Any ambiguity or uncertainty factors
</assessment-guidelines>

<extraction-results>
{EXTRACTION_RESULTS}
</extraction-results>

<attributes-definitions>
{ATTRIBUTE_NAMES_AND_DESCRIPTIONS}
</attributes-definitions>

<<CACHEPOINT>>

<document-text>
{DOCUMENT_TEXT}
</document-text>

<document-image>
{DOCUMENT_IMAGE}
</document-image>

<ocr-raw-results>
{OCR_TEXT_CONFIDENCE}
</ocr-raw-results>

<final-instructions>
Analyze the extraction results against the source document and provide confidence assessments. Return a JSON object with the following structure:

      {
        "attribute_name_1": {
          "confidence_score": 0.85,
          "confidence_reason": "Clear text evidence found in document header with high OCR confidence (0.98). Value matches exactly."
        },
        "attribute_name_2": {
          "confidence_score": 0.65,
          "confidence_reason": "Text is partially unclear due to poor scan quality. OCR confidence low (0.72) in this region."
        }
      }

Include assessments for ALL attributes present in the extraction results.
</final-instructions>"""
    },
    "classes": [
        {
        "name": "letter",
        "description": "A formal written message that is typically sent from one person to another",
        "attributes": [
            {
            "name": "sender_name",
            "description": "The name of the person or entity who wrote or sent the letter."
            },
            {
            "name": "sender_address",
            "description": "The physical address of the sender, typically appearing at the top of the letter."
            }
        ]
        },
        {
        "name": "form",
        "description": "A document with blank spaces for filling in information",
        "attributes": [
            {
            "name": "form_type",
            "description": "The category or purpose of the form."
            },
            {
            "name": "form_id",
            "description": "The unique identifier for the form."
            }
        ]
        },
        {
        "name": "email",
        "description": "An electronic message sent from one person to another over a computer network",
        "attributes": [
            {
            "name": "from_address",
            "description": "The email address of the sender."
            },
            {
            "name": "to_address",
            "description": "The email address of the primary recipient."
            }
        ]
        }
    ],
    "classification": {
        "temperature": 0,
        "model": "us.amazon.nova-pro-v1:0",
        "classificationMethod": "multimodalPageLevelClassification",
        "system_prompt": "You are a document classification system. Classify documents and return only JSON.",
        "top_k": 5,
        "task_prompt": "Classify this document. Return JSON with class field."
    },
    "extraction": {
        "temperature": 0,
        "model": "us.amazon.nova-pro-v1:0",
        "system_prompt": "You are a document assistant. Respond only with JSON. Never make up data.",
        "top_k": 5,
        "task_prompt": "Extract information from the document and return as JSON. Document type: {DOCUMENT_CLASS}. Text: {DOCUMENT_TEXT}. Image: {DOCUMENT_IMAGE}."
    }
}

print("Configuration created with assessment capabilities")
# Out:
# Configuration created with assessment capabilities

# %% [markdown]
# ## 5. Process Document with OCR

# %%
# Initialize a new Document
document = Document(
    id="rvl-cdip-package-assessment",
    input_bucket=input_bucket_name,
    input_key=sample_file_key,
    output_bucket=output_bucket_name,
    status=Status.QUEUED
)

print(f"Created document with ID: {document.id}")
print(f"Status: {document.status.value}")

# Create OCR service with Textract
ocr_service = ocr.OcrService(
    region=region,
    enhanced_features=['LAYOUT']
)

# Process document with OCR
print("\nProcessing document with OCR...")
start_time = time.time()
document = ocr_service.process_document(document)
ocr_time = time.time() - start_time

print(f"OCR processing completed in {ocr_time:.2f} seconds")
print(f"Document status: {document.status.value}")
print(f"Number of pages processed: {document.num_pages}")

# Show pages information
print("\nProcessed pages:")
for page_id, page in document.pages.items():
    print(f"Page {page_id}: Image URI: {page.image_uri}")
print("\nMetering:")
print(json.dumps(document.metering))
# Out:
# INFO:idp_common.ocr.service:OCR Service initialized with features: ['LAYOUT']
# Created document with ID: rvl-cdip-package-assessment
# Status: QUEUED
#
# Processing document with OCR...
# INFO:idp_common.ocr.service:Successfully extracted markdown text for page 7
# INFO:idp_common.ocr.service:Successfully extracted markdown text for page 3
# INFO:idp_common.ocr.service:Successfully extracted markdown text for page 5
# INFO:idp_common.ocr.service:Successfully extracted markdown text for page 9
# INFO:idp_common.ocr.service:Successfully extracted markdown text for page 10
# INFO:idp_common.ocr.service:Successfully extracted markdown text for page 6
# INFO:idp_common.ocr.service:Successfully extracted markdown text for page 8
# INFO:idp_common.ocr.service:Successfully extracted markdown text for page 1
# INFO:idp_common.ocr.service:Successfully extracted markdown text for page 2
# INFO:idp_common.ocr.service:Successfully extracted markdown text for page 4
# INFO:idp_common.ocr.service:Sorting 10 pages by page number
# INFO:idp_common.ocr.service:OCR processing completed in 6.45 seconds
# INFO:idp_common.ocr.service:Processed 10 pages, with 0 errors
# OCR processing completed in 6.45 seconds
# Document status: QUEUED
# Number of pages processed: 10
#
# Processed pages:
# Page 1: Image URI: s3://idp-notebook-assess-output-912625584728-us-west-2/sample-assessment-2025-06-06_20-51-46.pdf/pages/1/image.jpg
# Page 2: Image URI: s3://idp-notebook-assess-output-912625584728-us-west-2/sample-assessment-2025-06-06_20-51-46.pdf/pages/2/image.jpg
# Page 3: Image URI: s3://idp-notebook-assess-output-912625584728-us-west-2/sample-assessment-2025-06-06_20-51-46.pdf/pages/3/image.jpg
# Page 4: Image URI: s3://idp-notebook-assess-output-912625584728-us-west-2/sample-assessment-2025-06-06_20-51-46.pdf/pages/4/image.jpg
# Page 5: Image URI: s3://idp-notebook-assess-output-912625584728-us-west-2/sample-assessment-2025-06-06_20-51-46.pdf/pages/5/image.jpg
# Page 6: Image URI: s3://idp-notebook-assess-output-912625584728-us-west-2/sample-assessment-2025-06-06_20-51-46.pdf/pages/6/image.jpg
# Page 7: Image URI: s3://idp-notebook-assess-output-912625584728-us-west-2/sample-assessment-2025-06-06_20-51-46.pdf/pages/7/image.jpg
# Page 8: Image URI: s3://idp-notebook-assess-output-912625584728-us-west-2/sample-assessment-2025-06-06_20-51-46.pdf/pages/8/image.jpg
# Page 9: Image URI: s3://idp-notebook-assess-output-912625584728-us-west-2/sample-assessment-2025-06-06_20-51-46.pdf/pages/9/image.jpg
# Page 10: Image URI: s3://idp-notebook-assess-output-912625584728-us-west-2/sample-assessment-2025-06-06_20-51-46.pdf/pages/10/image.jpg
#
# Metering:
# {"OCR/textract/analyze_document-Layout": {"pages": 10}}

# %% [markdown]
# ## 6. Classify the Document

# %%
# Create classification service with Bedrock backend
classification_service = classification.ClassificationService(
    config=CONFIG, 
    backend="bedrock" 
)

# Classify the document
print("\nClassifying document...")
start_time = time.time()
document = classification_service.classify_document(document)
classification_time = time.time() - start_time
print(f"Classification completed in {classification_time:.2f} seconds")
print(f"Document status: {document.status.value}")

# Show classification results
if document.sections:
    print("\nDetected sections:")
    for section in document.sections:
        print(f"Section {section.section_id}: {section.classification}")
        print(f"  Pages: {section.page_ids}")
else:
    print("\nNo sections detected")

# Show page classification
print("\nPage-level classifications:")
for page_id, page in sorted(document.pages.items()):
    print(f"Page {page_id}: {page.classification}")
# Out:
# Classifying document...
# INFO:idp_common.bedrock.client:Bedrock request attempt 1/7:
# INFO:idp_common.bedrock.client:  - model: us.amazon.nova-pro-v1:0
# INFO:idp_common.bedrock.client:  - inferenceConfig: {'temperature': 0.0, 'topP': 0.1}
# INFO:idp_common.bedrock.client:  - system: [{'text': 'You are a document classification system. Classify documents and return only JSON.'}]
# INFO:idp_common.bedrock.client:  - messages: [{'role': 'user', 'content': [{'text': 'Classify this document. Return JSON with class field.'}, {'image': '[image_data]'}]}]
# INFO:idp_common.bedrock.client:  - additionalModelRequestFields: {'inferenceConfig': {'topK': 5}}
# INFO:idp_common.bedrock.client:Bedrock request attempt 1/7:
# INFO:idp_common.bedrock.client:  - model: us.amazon.nova-pro-v1:0
# INFO:idp_common.bedrock.client:  - inferenceConfig: {'temperature': 0.0, 'topP': 0.1}
# INFO:idp_common.bedrock.client:  - system: [{'text': 'You are a document classification system. Classify documents and return only JSON.'}]
# INFO:idp_common.bedrock.client:  - messages: [{'role': 'user', 'content': [{'text': 'Classify this document. Return JSON with class field.'}, {'image': '[image_data]'}]}]
# INFO:idp_common.bedrock.client:  - additionalModelRequestFields: {'inferenceConfig': {'topK': 5}}
# INFO:idp_common.bedrock.client:Bedrock request attempt 1/7:
# INFO:idp_common.bedrock.client:  - model: us.amazon.nova-pro-v1:0
# INFO:idp_common.bedrock.client:  - inferenceConfig: {'temperature': 0.0, 'topP': 0.1}
# INFO:idp_common.bedrock.client:  - system: [{'text': 'You are a document classification system. Classify documents and return only JSON.'}]
# INFO:idp_common.bedrock.client:  - messages: [{'role': 'user', 'content': [{'text': 'Classify this document. Return JSON with class field.'}, {'image': '[image_data]'}]}]
# INFO:idp_common.bedrock.client:  - additionalModelRequestFields: {'inferenceConfig': {'topK': 5}}
# INFO:idp_common.bedrock.client:Bedrock request attempt 1/7:
# INFO:idp_common.bedrock.client:  - model: us.amazon.nova-pro-v1:0
# INFO:idp_common.bedrock.client:  - inferenceConfig: {'temperature': 0.0, 'topP': 0.1}
# INFO:idp_common.bedrock.client:  - system: [{'text': 'You are a document classification system. Classify documents and return only JSON.'}]
# INFO:idp_common.bedrock.client:  - messages: [{'role': 'user', 'content': [{'text': 'Classify this document. Return JSON with class field.'}, {'image': '[image_data]'}]}]
# INFO:idp_common.bedrock.client:  - additionalModelRequestFields: {'inferenceConfig': {'topK': 5}}
# INFO:idp_common.bedrock.client:Bedrock request attempt 1/7:
# INFO:idp_common.bedrock.client:  - model: us.amazon.nova-pro-v1:0
# INFO:idp_common.bedrock.client:  - inferenceConfig: {'temperature': 0.0, 'topP': 0.1}
# INFO:idp_common.bedrock.client:  - system: [{'text': 'You are a document classification system. Classify documents and return only JSON.'}]
# INFO:idp_common.bedrock.client:  - messages: [{'role': 'user', 'content': [{'text': 'Classify this document. Return JSON with class field.'}, {'image': '[image_data]'}]}]
# INFO:idp_common.bedrock.client:  - additionalModelRequestFields: {'inferenceConfig': {'topK': 5}}
# INFO:idp_common.bedrock.client:Bedrock request attempt 1/7:
# INFO:idp_common.bedrock.client:  - model: us.amazon.nova-pro-v1:0
# INFO:idp_common.bedrock.client:  - inferenceConfig: {'temperature': 0.0, 'topP': 0.1}
# INFO:idp_common.bedrock.client:  - system: [{'text': 'You are a document classification system. Classify documents and return only JSON.'}]
# INFO:idp_common.bedrock.client:  - messages: [{'role': 'user', 'content': [{'text': 'Classify this document. Return JSON with class field.'}, {'image': '[image_data]'}]}]
# INFO:idp_common.bedrock.client:  - additionalModelRequestFields: {'inferenceConfig': {'topK': 5}}
# INFO:idp_common.bedrock.client:Bedrock request attempt 1/7:
# INFO:idp_common.bedrock.client:  - model: us.amazon.nova-pro-v1:0
# INFO:idp_common.bedrock.client:  - inferenceConfig: {'temperature': 0.0, 'topP': 0.1}
# INFO:idp_common.bedrock.client:  - system: [{'text': 'You are a document classification system. Classify documents and return only JSON.'}]
# INFO:idp_common.bedrock.client:  - messages: [{'role': 'user', 'content': [{'text': 'Classify this document. Return JSON with class field.'}, {'image': '[image_data]'}]}]
# INFO:idp_common.bedrock.client:  - additionalModelRequestFields: {'inferenceConfig': {'topK': 5}}
# INFO:idp_common.bedrock.client:Bedrock request attempt 1/7:
# INFO:idp_common.bedrock.client:  - model: us.amazon.nova-pro-v1:0
# INFO:idp_common.bedrock.client:  - inferenceConfig: {'temperature': 0.0, 'topP': 0.1}
# INFO:idp_common.bedrock.client:  - system: [{'text': 'You are a document classification system. Classify documents and return only JSON.'}]
# INFO:idp_common.bedrock.client:  - messages: [{'role': 'user', 'content': [{'text': 'Classify this document. Return JSON with class field.'}, {'image': '[image_data]'}]}]
# INFO:idp_common.bedrock.client:  - additionalModelRequestFields: {'inferenceConfig': {'topK': 5}}
# INFO:idp_common.bedrock.client:Bedrock request attempt 1/7:
# INFO:idp_common.bedrock.client:  - model: us.amazon.nova-pro-v1:0
# INFO:idp_common.bedrock.client:  - inferenceConfig: {'temperature': 0.0, 'topP': 0.1}
# INFO:idp_common.bedrock.client:  - system: [{'text': 'You are a document classification system. Classify documents and return only JSON.'}]
# INFO:idp_common.bedrock.client:  - messages: [{'role': 'user', 'content': [{'text': 'Classify this document. Return JSON with class field.'}, {'image': '[image_data]'}]}]
# INFO:idp_common.bedrock.client:  - additionalModelRequestFields: {'inferenceConfig': {'topK': 5}}
# INFO:idp_common.bedrock.client:Bedrock request attempt 1/7:
# INFO:idp_common.bedrock.client:  - model: us.amazon.nova-pro-v1:0
# INFO:idp_common.bedrock.client:  - inferenceConfig: {'temperature': 0.0, 'topP': 0.1}
# INFO:idp_common.bedrock.client:  - system: [{'text': 'You are a document classification system. Classify documents and return only JSON.'}]
# INFO:idp_common.bedrock.client:  - messages: [{'role': 'user', 'content': [{'text': 'Classify this document. Return JSON with class field.'}, {'image': '[image_data]'}]}]
# INFO:idp_common.bedrock.client:  - additionalModelRequestFields: {'inferenceConfig': {'topK': 5}}
# INFO:idp_common.bedrock.client:Bedrock request successful after 1 attempts. Duration: 1.11s
# DEBUG:idp_common.bedrock.client:Response: {'ResponseMetadata': {'RequestId': 'da776852-3f80-4dc4-8d40-e37fbbd16512', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Fri, 06 Jun 2025 20:51:55 GMT', 'content-type': 'application/json', 'content-length': '230', 'connection': 'keep-alive', 'x-amzn-requestid': 'da776852-3f80-4dc4-8d40-e37fbbd16512'}, 'RetryAttempts': 0}, 'output': {'message': {'role': 'assistant', 'content': [{'text': '{\n  "class": "Business Communication"\n}'}]}}, 'stopReason': 'end_turn', 'usage': {'inputTokens': 1637, 'outputTokens': 10, 'totalTokens': 1647}, 'metrics': {'latencyMs': 779}}
# INFO:idp_common.bedrock.client:Token Usage: {'inputTokens': 1637, 'outputTokens': 10, 'totalTokens': 1647}
# INFO:idp_common.bedrock.client:Bedrock request successful after 1 attempts. Duration: 1.16s
# DEBUG:idp_common.bedrock.client:Response: {'ResponseMetadata': {'RequestId': '91e17dfa-f4b6-45a1-9586-2c1265360262', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Fri, 06 Jun 2025 20:51:55 GMT', 'content-type': 'application/json', 'content-length': '244', 'connection': 'keep-alive', 'x-amzn-requestid': '91e17dfa-f4b6-45a1-9586-2c1265360262'}, 'RetryAttempts': 0}, 'output': {'message': {'role': 'assistant', 'content': [{'text': '```json\n{\n  "class": "Internal Communication"\n}\n```'}]}}, 'stopReason': 'end_turn', 'usage': {'inputTokens': 1637, 'outputTokens': 14, 'totalTokens': 1651}, 'metrics': {'latencyMs': 835}}
# INFO:idp_common.bedrock.client:Token Usage: {'inputTokens': 1637, 'outputTokens': 14, 'totalTokens': 1651}
# INFO:idp_common.bedrock.client:Bedrock request successful after 1 attempts. Duration: 1.25s
# DEBUG:idp_common.bedrock.client:Response: {'ResponseMetadata': {'RequestId': '56e5ba6e-c33d-48f4-8fe9-2825e179e113', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Fri, 06 Jun 2025 20:51:55 GMT', 'content-type': 'application/json', 'content-length': '214', 'connection': 'keep-alive', 'x-amzn-requestid': '56e5ba6e-c33d-48f4-8fe9-2825e179e113'}, 'RetryAttempts': 0}, 'output': {'message': {'role': 'assistant', 'content': [{'text': '{\n  "class": "Invoice"\n}'}]}}, 'stopReason': 'end_turn', 'usage': {'inputTokens': 1637, 'outputTokens': 9, 'totalTokens': 1646}, 'metrics': {'latencyMs': 867}}
# INFO:idp_common.bedrock.client:Token Usage: {'inputTokens': 1637, 'outputTokens': 9, 'totalTokens': 1646}
# INFO:idp_common.bedrock.client:Bedrock request successful after 1 attempts. Duration: 1.36s
# DEBUG:idp_common.bedrock.client:Response: {'ResponseMetadata': {'RequestId': '449d34fc-650e-4bfc-b265-b67fd3db8694', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Fri, 06 Jun 2025 20:51:55 GMT', 'content-type': 'application/json', 'content-length': '250', 'connection': 'keep-alive', 'x-amzn-requestid': '449d34fc-650e-4bfc-b265-b67fd3db8694'}, 'RetryAttempts': 0}, 'output': {'message': {'role': 'assistant', 'content': [{'text': '```json\n{\n  "class": "Customer Satisfaction Survey"\n}\n```'}]}}, 'stopReason': 'end_turn', 'usage': {'inputTokens': 1637, 'outputTokens': 15, 'totalTokens': 1652}, 'metrics': {'latencyMs': 933}}
# INFO:idp_common.bedrock.client:Token Usage: {'inputTokens': 1637, 'outputTokens': 15, 'totalTokens': 1652}
# WARNING:idp_common.classification.service:Unknown document type 'Internal Communication' for page 3, valid types are: form, email, letter
# WARNING:idp_common.classification.service:Unknown document type 'Invoice' for page 5, valid types are: form, email, letter
# WARNING:idp_common.classification.service:Unknown document type 'Business Communication' for page 10, valid types are: form, email, letter
# WARNING:idp_common.classification.service:Unknown document type 'Customer Satisfaction Survey' for page 7, valid types are: form, email, letter
# WARNING:idp_common.bedrock.client:Bedrock throttling occurred (attempt 1/7). Error: Too many requests, please wait before trying again.. Backing off for 2.24s
# WARNING:idp_common.bedrock.client:Bedrock throttling occurred (attempt 1/7). Error: Too many requests, please wait before trying again.. Backing off for 2.58s
# WARNING:idp_common.bedrock.client:Bedrock throttling occurred (attempt 1/7). Error: Too many requests, please wait before trying again.. Backing off for 2.62s
# INFO:idp_common.bedrock.client:Bedrock request attempt 2/7:
# INFO:idp_common.bedrock.client:  - model: us.amazon.nova-pro-v1:0
# INFO:idp_common.bedrock.client:  - inferenceConfig: {'temperature': 0.0, 'topP': 0.1}
# INFO:idp_common.bedrock.client:  - system: [{'text': 'You are a document classification system. Classify documents and return only JSON.'}]
# INFO:idp_common.bedrock.client:  - messages: [{'role': 'user', 'content': [{'text': 'Classify this document. Return JSON with class field.'}, {'image': '[image_data]'}]}]
# INFO:idp_common.bedrock.client:  - additionalModelRequestFields: {'inferenceConfig': {'topK': 5}}
# INFO:idp_common.bedrock.client:Bedrock request attempt 2/7:
# INFO:idp_common.bedrock.client:  - model: us.amazon.nova-pro-v1:0
# INFO:idp_common.bedrock.client:  - inferenceConfig: {'temperature': 0.0, 'topP': 0.1}
# INFO:idp_common.bedrock.client:  - system: [{'text': 'You are a document classification system. Classify documents and return only JSON.'}]
# INFO:idp_common.bedrock.client:  - messages: [{'role': 'user', 'content': [{'text': 'Classify this document. Return JSON with class field.'}, {'image': '[image_data]'}]}]
# INFO:idp_common.bedrock.client:  - additionalModelRequestFields: {'inferenceConfig': {'topK': 5}}
# INFO:idp_common.bedrock.client:Bedrock request attempt 2/7:
# INFO:idp_common.bedrock.client:  - model: us.amazon.nova-pro-v1:0
# INFO:idp_common.bedrock.client:  - inferenceConfig: {'temperature': 0.0, 'topP': 0.1}
# INFO:idp_common.bedrock.client:  - system: [{'text': 'You are a document classification system. Classify documents and return only JSON.'}]
# INFO:idp_common.bedrock.client:  - messages: [{'role': 'user', 'content': [{'text': 'Classify this document. Return JSON with class field.'}, {'image': '[image_data]'}]}]
# INFO:idp_common.bedrock.client:  - additionalModelRequestFields: {'inferenceConfig': {'topK': 5}}
# WARNING:idp_common.bedrock.client:Bedrock throttling occurred (attempt 1/7). Error: Too many requests, please wait before trying again.. Backing off for 2.53s
# WARNING:idp_common.bedrock.client:Bedrock throttling occurred (attempt 1/7). Error: Too many requests, please wait before trying again.. Backing off for 2.41s
# INFO:idp_common.bedrock.client:Bedrock request attempt 2/7:
# INFO:idp_common.bedrock.client:  - model: us.amazon.nova-pro-v1:0
# INFO:idp_common.bedrock.client:  - inferenceConfig: {'temperature': 0.0, 'topP': 0.1}
# INFO:idp_common.bedrock.client:  - system: [{'text': 'You are a document classification system. Classify documents and return only JSON.'}]
# INFO:idp_common.bedrock.client:  - messages: [{'role': 'user', 'content': [{'text': 'Classify this document. Return JSON with class field.'}, {'image': '[image_data]'}]}]
# INFO:idp_common.bedrock.client:  - additionalModelRequestFields: {'inferenceConfig': {'topK': 5}}
# INFO:idp_common.bedrock.client:Bedrock request attempt 2/7:
# INFO:idp_common.bedrock.client:  - model: us.amazon.nova-pro-v1:0
# INFO:idp_common.bedrock.client:  - inferenceConfig: {'temperature': 0.0, 'topP': 0.1}
# INFO:idp_common.bedrock.client:  - system: [{'text': 'You are a document classification system. Classify documents and return only JSON.'}]
# INFO:idp_common.bedrock.client:  - messages: [{'role': 'user', 'content': [{'text': 'Classify this document. Return JSON with class field.'}, {'image': '[image_data]'}]}]
# INFO:idp_common.bedrock.client:  - additionalModelRequestFields: {'inferenceConfig': {'topK': 5}}
# WARNING:idp_common.bedrock.client:Bedrock throttling occurred (attempt 2/7). Error: Too many requests, please wait before trying again.. Backing off for 4.43s
# WARNING:idp_common.bedrock.client:Bedrock throttling occurred (attempt 1/7). Error: Too many requests, please wait before trying again.. Backing off for 2.32s
# WARNING:idp_common.bedrock.client:Bedrock throttling occurred (attempt 2/7). Error: Too many requests, please wait before trying again.. Backing off for 4.07s
# INFO:idp_common.bedrock.client:Bedrock request attempt 2/7:
# INFO:idp_common.bedrock.client:  - model: us.amazon.nova-pro-v1:0
# INFO:idp_common.bedrock.client:  - inferenceConfig: {'temperature': 0.0, 'topP': 0.1}
# INFO:idp_common.bedrock.client:  - system: [{'text': 'You are a document classification system. Classify documents and return only JSON.'}]
# INFO:idp_common.bedrock.client:  - messages: [{'role': 'user', 'content': [{'text': 'Classify this document. Return JSON with class field.'}, {'image': '[image_data]'}]}]
# INFO:idp_common.bedrock.client:  - additionalModelRequestFields: {'inferenceConfig': {'topK': 5}}
# INFO:idp_common.bedrock.client:Bedrock request successful after 2 attempts. Duration: 1.15s
# DEBUG:idp_common.bedrock.client:Response: {'ResponseMetadata': {'RequestId': '2fcac52d-af9b-4771-9ba5-c89488e307fb', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Fri, 06 Jun 2025 20:52:11 GMT', 'content-type': 'application/json', 'content-length': '224', 'connection': 'keep-alive', 'x-amzn-requestid': '2fcac52d-af9b-4771-9ba5-c89488e307fb'}, 'RetryAttempts': 0}, 'output': {'message': {'role': 'assistant', 'content': [{'text': '{\n  "class": "Curriculum Vitae"\n}'}]}}, 'stopReason': 'end_turn', 'usage': {'inputTokens': 1637, 'outputTokens': 13, 'totalTokens': 1650}, 'metrics': {'latencyMs': 868}}
# INFO:idp_common.bedrock.client:Token Usage: {'inputTokens': 1637, 'outputTokens': 13, 'totalTokens': 1650}
# WARNING:idp_common.bedrock.client:Bedrock throttling occurred (attempt 2/7). Error: Too many requests, please wait before trying again.. Backing off for 4.94s
# WARNING:idp_common.classification.service:Unknown document type 'Curriculum Vitae' for page 9, valid types are: form, email, letter
# INFO:idp_common.bedrock.client:Bedrock request attempt 3/7:
# INFO:idp_common.bedrock.client:  - model: us.amazon.nova-pro-v1:0
# INFO:idp_common.bedrock.client:  - inferenceConfig: {'temperature': 0.0, 'topP': 0.1}
# INFO:idp_common.bedrock.client:  - system: [{'text': 'You are a document classification system. Classify documents and return only JSON.'}]
# INFO:idp_common.bedrock.client:  - messages: [{'role': 'user', 'content': [{'text': 'Classify this document. Return JSON with class field.'}, {'image': '[image_data]'}]}]
# INFO:idp_common.bedrock.client:  - additionalModelRequestFields: {'inferenceConfig': {'topK': 5}}
# INFO:idp_common.bedrock.client:Bedrock request attempt 3/7:
# INFO:idp_common.bedrock.client:  - model: us.amazon.nova-pro-v1:0
# INFO:idp_common.bedrock.client:  - inferenceConfig: {'temperature': 0.0, 'topP': 0.1}
# INFO:idp_common.bedrock.client:  - system: [{'text': 'You are a document classification system. Classify documents and return only JSON.'}]
# INFO:idp_common.bedrock.client:  - messages: [{'role': 'user', 'content': [{'text': 'Classify this document. Return JSON with class field.'}, {'image': '[image_data]'}]}]
# INFO:idp_common.bedrock.client:  - additionalModelRequestFields: {'inferenceConfig': {'topK': 5}}
# WARNING:idp_common.bedrock.client:Bedrock throttling occurred (attempt 2/7). Error: Too many requests, please wait before trying again.. Backing off for 4.65s
# INFO:idp_common.bedrock.client:Bedrock request attempt 3/7:
# INFO:idp_common.bedrock.client:  - model: us.amazon.nova-pro-v1:0
# INFO:idp_common.bedrock.client:  - inferenceConfig: {'temperature': 0.0, 'topP': 0.1}
# INFO:idp_common.bedrock.client:  - system: [{'text': 'You are a document classification system. Classify documents and return only JSON.'}]
# INFO:idp_common.bedrock.client:  - messages: [{'role': 'user', 'content': [{'text': 'Classify this document. Return JSON with class field.'}, {'image': '[image_data]'}]}]
# INFO:idp_common.bedrock.client:  - additionalModelRequestFields: {'inferenceConfig': {'topK': 5}}
# WARNING:idp_common.bedrock.client:Bedrock throttling occurred (attempt 3/7). Error: Too many requests, please wait before trying again.. Backing off for 8.72s
# WARNING:idp_common.bedrock.client:Bedrock throttling occurred (attempt 2/7). Error: Too many requests, please wait before trying again.. Backing off for 4.57s
# INFO:idp_common.bedrock.client:Bedrock request attempt 3/7:
# INFO:idp_common.bedrock.client:  - model: us.amazon.nova-pro-v1:0
# INFO:idp_common.bedrock.client:  - inferenceConfig: {'temperature': 0.0, 'topP': 0.1}
# INFO:idp_common.bedrock.client:  - system: [{'text': 'You are a document classification system. Classify documents and return only JSON.'}]
# INFO:idp_common.bedrock.client:  - messages: [{'role': 'user', 'content': [{'text': 'Classify this document. Return JSON with class field.'}, {'image': '[image_data]'}]}]
# INFO:idp_common.bedrock.client:  - additionalModelRequestFields: {'inferenceConfig': {'topK': 5}}
# INFO:idp_common.bedrock.client:Bedrock request attempt 3/7:
# INFO:idp_common.bedrock.client:  - model: us.amazon.nova-pro-v1:0
# INFO:idp_common.bedrock.client:  - inferenceConfig: {'temperature': 0.0, 'topP': 0.1}
# INFO:idp_common.bedrock.client:  - system: [{'text': 'You are a document classification system. Classify documents and return only JSON.'}]
# INFO:idp_common.bedrock.client:  - messages: [{'role': 'user', 'content': [{'text': 'Classify this document. Return JSON with class field.'}, {'image': '[image_data]'}]}]
# INFO:idp_common.bedrock.client:  - additionalModelRequestFields: {'inferenceConfig': {'topK': 5}}
# WARNING:idp_common.bedrock.client:Bedrock throttling occurred (attempt 3/7). Error: Too many requests, please wait before trying again.. Backing off for 8.46s
# INFO:idp_common.bedrock.client:Bedrock request attempt 4/7:
# INFO:idp_common.bedrock.client:  - model: us.amazon.nova-pro-v1:0
# INFO:idp_common.bedrock.client:  - inferenceConfig: {'temperature': 0.0, 'topP': 0.1}
# INFO:idp_common.bedrock.client:  - system: [{'text': 'You are a document classification system. Classify documents and return only JSON.'}]
# INFO:idp_common.bedrock.client:  - messages: [{'role': 'user', 'content': [{'text': 'Classify this document. Return JSON with class field.'}, {'image': '[image_data]'}]}]
# INFO:idp_common.bedrock.client:  - additionalModelRequestFields: {'inferenceConfig': {'topK': 5}}
# INFO:idp_common.bedrock.client:Bedrock request successful after 3 attempts. Duration: 9.24s
# DEBUG:idp_common.bedrock.client:Response: {'ResponseMetadata': {'RequestId': '4b6f1ae6-22e1-4cf2-b80c-19e2d1967e62', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Fri, 06 Jun 2025 20:52:25 GMT', 'content-type': 'application/json', 'content-length': '227', 'connection': 'keep-alive', 'x-amzn-requestid': '4b6f1ae6-22e1-4cf2-b80c-19e2d1967e62'}, 'RetryAttempts': 4}, 'output': {'message': {'role': 'assistant', 'content': [{'text': '{\n  "class": "Biographical Sketch"\n}'}]}}, 'stopReason': 'end_turn', 'usage': {'inputTokens': 1637, 'outputTokens': 11, 'totalTokens': 1648}, 'metrics': {'latencyMs': 931}}
# INFO:idp_common.bedrock.client:Token Usage: {'inputTokens': 1637, 'outputTokens': 11, 'totalTokens': 1648}
# WARNING:idp_common.classification.service:Unknown document type 'Biographical Sketch' for page 8, valid types are: form, email, letter
# WARNING:idp_common.bedrock.client:Bedrock throttling occurred (attempt 3/7). Error: Too many requests, please wait before trying again.. Backing off for 8.20s
# INFO:idp_common.bedrock.client:Bedrock request attempt 4/7:
# INFO:idp_common.bedrock.client:  - model: us.amazon.nova-pro-v1:0
# INFO:idp_common.bedrock.client:  - inferenceConfig: {'temperature': 0.0, 'topP': 0.1}
# INFO:idp_common.bedrock.client:  - system: [{'text': 'You are a document classification system. Classify documents and return only JSON.'}]
# INFO:idp_common.bedrock.client:  - messages: [{'role': 'user', 'content': [{'text': 'Classify this document. Return JSON with class field.'}, {'image': '[image_data]'}]}]
# INFO:idp_common.bedrock.client:  - additionalModelRequestFields: {'inferenceConfig': {'topK': 5}}
# WARNING:idp_common.bedrock.client:Bedrock throttling occurred (attempt 3/7). Error: Too many requests, please wait before trying again.. Backing off for 8.97s
# WARNING:idp_common.bedrock.client:Bedrock throttling occurred (attempt 4/7). Error: Too many requests, please wait before trying again.. Backing off for 16.92s
# INFO:idp_common.bedrock.client:Bedrock request attempt 4/7:
# INFO:idp_common.bedrock.client:  - model: us.amazon.nova-pro-v1:0
# INFO:idp_common.bedrock.client:  - inferenceConfig: {'temperature': 0.0, 'topP': 0.1}
# INFO:idp_common.bedrock.client:  - system: [{'text': 'You are a document classification system. Classify documents and return only JSON.'}]
# INFO:idp_common.bedrock.client:  - messages: [{'role': 'user', 'content': [{'text': 'Classify this document. Return JSON with class field.'}, {'image': '[image_data]'}]}]
# INFO:idp_common.bedrock.client:  - additionalModelRequestFields: {'inferenceConfig': {'topK': 5}}
# WARNING:idp_common.bedrock.client:Bedrock throttling occurred (attempt 4/7). Error: Too many requests, please wait before trying again.. Backing off for 16.91s
# INFO:idp_common.bedrock.client:Bedrock request attempt 4/7:
# INFO:idp_common.bedrock.client:  - model: us.amazon.nova-pro-v1:0
# INFO:idp_common.bedrock.client:  - inferenceConfig: {'temperature': 0.0, 'topP': 0.1}
# INFO:idp_common.bedrock.client:  - system: [{'text': 'You are a document classification system. Classify documents and return only JSON.'}]
# INFO:idp_common.bedrock.client:  - messages: [{'role': 'user', 'content': [{'text': 'Classify this document. Return JSON with class field.'}, {'image': '[image_data]'}]}]
# INFO:idp_common.bedrock.client:  - additionalModelRequestFields: {'inferenceConfig': {'topK': 5}}
# INFO:idp_common.bedrock.client:Bedrock request successful after 4 attempts. Duration: 4.30s
# DEBUG:idp_common.bedrock.client:Response: {'ResponseMetadata': {'RequestId': '4f3db2c5-8369-41b7-9d24-765505ae3b65', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Fri, 06 Jun 2025 20:52:40 GMT', 'content-type': 'application/json', 'content-length': '239', 'connection': 'keep-alive', 'x-amzn-requestid': '4f3db2c5-8369-41b7-9d24-765505ae3b65'}, 'RetryAttempts': 2}, 'output': {'message': {'role': 'assistant', 'content': [{'text': '{\n  "class": "LAB SERVICES CONSISTENCY REPORT"\n}'}]}}, 'stopReason': 'end_turn', 'usage': {'inputTokens': 1637, 'outputTokens': 15, 'totalTokens': 1652}, 'metrics': {'latencyMs': 897}}
# INFO:idp_common.bedrock.client:Token Usage: {'inputTokens': 1637, 'outputTokens': 15, 'totalTokens': 1652}
# WARNING:idp_common.classification.service:Unknown document type 'LAB SERVICES CONSISTENCY REPORT' for page 2, valid types are: form, email, letter
# WARNING:idp_common.bedrock.client:Bedrock throttling occurred (attempt 4/7). Error: Too many requests, please wait before trying again.. Backing off for 16.48s
# INFO:idp_common.bedrock.client:Bedrock request attempt 5/7:
# INFO:idp_common.bedrock.client:  - model: us.amazon.nova-pro-v1:0
# INFO:idp_common.bedrock.client:  - inferenceConfig: {'temperature': 0.0, 'topP': 0.1}
# INFO:idp_common.bedrock.client:  - system: [{'text': 'You are a document classification system. Classify documents and return only JSON.'}]
# INFO:idp_common.bedrock.client:  - messages: [{'role': 'user', 'content': [{'text': 'Classify this document. Return JSON with class field.'}, {'image': '[image_data]'}]}]
# INFO:idp_common.bedrock.client:  - additionalModelRequestFields: {'inferenceConfig': {'topK': 5}}
# INFO:idp_common.bedrock.client:Bedrock request attempt 5/7:
# INFO:idp_common.bedrock.client:  - model: us.amazon.nova-pro-v1:0
# INFO:idp_common.bedrock.client:  - inferenceConfig: {'temperature': 0.0, 'topP': 0.1}
# INFO:idp_common.bedrock.client:  - system: [{'text': 'You are a document classification system. Classify documents and return only JSON.'}]
# INFO:idp_common.bedrock.client:  - messages: [{'role': 'user', 'content': [{'text': 'Classify this document. Return JSON with class field.'}, {'image': '[image_data]'}]}]
# INFO:idp_common.bedrock.client:  - additionalModelRequestFields: {'inferenceConfig': {'topK': 5}}
# INFO:idp_common.bedrock.client:Bedrock request successful after 5 attempts. Duration: 4.28s
# DEBUG:idp_common.bedrock.client:Response: {'ResponseMetadata': {'RequestId': '7b7e0f8f-893e-40fd-91f5-75dc9510d654', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Fri, 06 Jun 2025 20:52:56 GMT', 'content-type': 'application/json', 'content-length': '231', 'connection': 'keep-alive', 'x-amzn-requestid': '7b7e0f8f-893e-40fd-91f5-75dc9510d654'}, 'RetryAttempts': 2}, 'output': {'message': {'role': 'assistant', 'content': [{'text': '{\n  "class": "Government Announcement"\n}'}]}}, 'stopReason': 'end_turn', 'usage': {'inputTokens': 1637, 'outputTokens': 10, 'totalTokens': 1647}, 'metrics': {'latencyMs': 884}}
# INFO:idp_common.bedrock.client:Token Usage: {'inputTokens': 1637, 'outputTokens': 10, 'totalTokens': 1647}
# WARNING:idp_common.classification.service:Unknown document type 'Government Announcement' for page 6, valid types are: form, email, letter
# INFO:idp_common.bedrock.client:Bedrock request attempt 5/7:
# INFO:idp_common.bedrock.client:  - model: us.amazon.nova-pro-v1:0
# INFO:idp_common.bedrock.client:  - inferenceConfig: {'temperature': 0.0, 'topP': 0.1}
# INFO:idp_common.bedrock.client:  - system: [{'text': 'You are a document classification system. Classify documents and return only JSON.'}]
# INFO:idp_common.bedrock.client:  - messages: [{'role': 'user', 'content': [{'text': 'Classify this document. Return JSON with class field.'}, {'image': '[image_data]'}]}]
# INFO:idp_common.bedrock.client:  - additionalModelRequestFields: {'inferenceConfig': {'topK': 5}}
# WARNING:idp_common.bedrock.client:Bedrock throttling occurred (attempt 5/7). Error: Too many requests, please wait before trying again.. Backing off for 32.64s
# INFO:idp_common.bedrock.client:Bedrock request successful after 5 attempts. Duration: 3.06s
# DEBUG:idp_common.bedrock.client:Response: {'ResponseMetadata': {'RequestId': '9b7750c0-7e36-4402-aee5-4020d44771b2', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Fri, 06 Jun 2025 20:53:11 GMT', 'content-type': 'application/json', 'content-length': '223', 'connection': 'keep-alive', 'x-amzn-requestid': '9b7750c0-7e36-4402-aee5-4020d44771b2'}, 'RetryAttempts': 2}, 'output': {'message': {'role': 'assistant', 'content': [{'text': '{\n  "class": "lobbying letter"\n}'}]}}, 'stopReason': 'end_turn', 'usage': {'inputTokens': 1637, 'outputTokens': 11, 'totalTokens': 1648}, 'metrics': {'latencyMs': 886}}
# INFO:idp_common.bedrock.client:Token Usage: {'inputTokens': 1637, 'outputTokens': 11, 'totalTokens': 1648}
# WARNING:idp_common.classification.service:Unknown document type 'lobbying letter' for page 1, valid types are: form, email, letter
# INFO:idp_common.bedrock.client:Bedrock request attempt 6/7:
# INFO:idp_common.bedrock.client:  - model: us.amazon.nova-pro-v1:0
# INFO:idp_common.bedrock.client:  - inferenceConfig: {'temperature': 0.0, 'topP': 0.1}
# INFO:idp_common.bedrock.client:  - system: [{'text': 'You are a document classification system. Classify documents and return only JSON.'}]
# INFO:idp_common.bedrock.client:  - messages: [{'role': 'user', 'content': [{'text': 'Classify this document. Return JSON with class field.'}, {'image': '[image_data]'}]}]
# INFO:idp_common.bedrock.client:  - additionalModelRequestFields: {'inferenceConfig': {'topK': 5}}
# INFO:idp_common.bedrock.client:Bedrock request successful after 6 attempts. Duration: 1.18s
# DEBUG:idp_common.bedrock.client:Response: {'ResponseMetadata': {'RequestId': '1aec62a5-151b-4c0a-98d0-ea46b500e2c6', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Fri, 06 Jun 2025 20:53:42 GMT', 'content-type': 'application/json', 'content-length': '225', 'connection': 'keep-alive', 'x-amzn-requestid': '1aec62a5-151b-4c0a-98d0-ea46b500e2c6'}, 'RetryAttempts': 0}, 'output': {'message': {'role': 'assistant', 'content': [{'text': '{\n  "class": "Scientific Report"\n}'}]}}, 'stopReason': 'end_turn', 'usage': {'inputTokens': 1637, 'outputTokens': 10, 'totalTokens': 1647}, 'metrics': {'latencyMs': 909}}
# INFO:idp_common.bedrock.client:Token Usage: {'inputTokens': 1637, 'outputTokens': 10, 'totalTokens': 1647}
# WARNING:idp_common.classification.service:Unknown document type 'Scientific Report' for page 4, valid types are: form, email, letter
# Classification completed in 109.46 seconds
# Document status: QUEUED
#
# Detected sections:
# Section 1: lobbying letter
#   Pages: ['1']
# Section 2: LAB SERVICES CONSISTENCY REPORT
#   Pages: ['2']
# Section 3: Internal Communication
#   Pages: ['3']
# Section 4: Scientific Report
#   Pages: ['4']
# Section 5: Invoice
#   Pages: ['5']
# Section 6: Government Announcement
#   Pages: ['6']
# Section 7: Customer Satisfaction Survey
#   Pages: ['7']
# Section 8: Biographical Sketch
#   Pages: ['8']
# Section 9: Curriculum Vitae
#   Pages: ['9']
# Section 10: Business Communication
#   Pages: ['10']
#
# Page-level classifications:
# Page 1: lobbying letter
# Page 10: Business Communication
# Page 2: LAB SERVICES CONSISTENCY REPORT
# Page 3: Internal Communication
# Page 4: Scientific Report
# Page 5: Invoice
# Page 6: Government Announcement
# Page 7: Customer Satisfaction Survey
# Page 8: Biographical Sketch
# Page 9: Curriculum Vitae

# %% [markdown]
# ## 7. Extract Information from Document Sections

# %%
# Create extraction service with Bedrock
extraction_service = extraction.ExtractionService(config=CONFIG)

print("\nExtracting information from document sections...")

n = 3 # Only process first 3 sections to save time
# Process each section directly using the section_id
for section in document.sections[:n]:  
    print(f"\nProcessing section {section.section_id} (class: {section.classification})")
    
    # Process section directly with the original document
    start_time = time.time()
    document = extraction_service.process_document_section(
        document=document,
        section_id=section.section_id
    )
    extraction_time = time.time() - start_time
    print(f"Extraction for section {section.section_id} completed in {extraction_time:.2f} seconds")
    
print(f"\nExtraction for first {n} sections complete.")
# Out:
# Extracting information from document sections...
#
# Processing section 1 (class: lobbying letter)
# INFO:idp_common.bedrock.client:Bedrock request attempt 1/7:
# INFO:idp_common.bedrock.client:  - model: us.amazon.nova-pro-v1:0
# INFO:idp_common.bedrock.client:  - inferenceConfig: {'temperature': 0.0, 'topP': 0.1}
# INFO:idp_common.bedrock.client:  - system: [{'text': 'You are a document assistant. Respond only with JSON. Never make up data.'}]
# INFO:idp_common.bedrock.client:  - messages: [{'role': 'user', 'content': [{'text': 'Extract information from the document and return as JSON. Document type: lobbying letter. Text: \n\nWESTERN DARK FIRED TOBACCO GROWERS\' ASSOCIATION \n\n206 Maple Street P.O. Box 1056 Murray Kentucky 42071-1056 \n\n(502) 753-3341 FAX (502) 753-0069/3342 \n\nOctober 31, 1995 \n\nThe Honorable Wendell H. Ford United States Senate Washington, D. C. 20510 \n\nDear Senator Ford: \n\nOn behalf of the Western Dark Fired Tobacco Growers\' Association and the 9,000 tobacco producers it represents, I an obligated to convey our strong opposition to the "Commitment to our Children\' petition being circulated by several Members of Congress. \n\nIn the tobacco industry, no one wants young people to consume tobacco products and age restriction laws are on the books in every state in the nation. We must take action to better enforce these laws, not create more bureaucracy. \n\ngovernment bureaucracy, thus destroying our family farms and There are those in our society who want to add inefficient hampering an adult\'s First Amendment right to the freedom of choice in using a legal product. \n\nYou may have been approached by those who say they are supporting Administration (FDA) regulation of tobacco. However, if FDA is given the authority to regulate tobacco because it is a nicotine the cause of youth smoking prevention by pushing the Food and Drug delivery device\', farmers will be forced to deal with yet another monitored by the United States Department of Agriculture the government agency. Already our producers deal with and are Administration and many others. We know first hand what a Environmental Protection Agency, the Occupational Safety and Health We certainly need your support and involvement to prevent FDA from nightmare federal government regulations can create for farmers. joining the ranks of federal tobacco regulators. \n\nChildren" petition, looking at it for what it is: more anti-tobacco I urge you to consider the consequences of the "Commitment to Our indoctrination, rather than a solution to a problem which everyone starting with parents, should address in a responsible manner. \n\nSincerely, Will E tlack Will E. Clark General Manager \n\nTNJB 0008497\n. Image: '}, {'image': '[image_data]'}, {'text': '.'}]}]
# INFO:idp_common.bedrock.client:  - additionalModelRequestFields: {'inferenceConfig': {'topK': 5}}
# INFO:idp_common.bedrock.client:Bedrock request successful after 1 attempts. Duration: 5.28s
# DEBUG:idp_common.bedrock.client:Response: {'ResponseMetadata': {'RequestId': 'a0c92647-6d85-4755-86f9-e793a938fe17', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Fri, 06 Jun 2025 20:53:49 GMT', 'content-type': 'application/json', 'content-length': '1497', 'connection': 'keep-alive', 'x-amzn-requestid': 'a0c92647-6d85-4755-86f9-e793a938fe17'}, 'RetryAttempts': 0}, 'output': {'message': {'role': 'assistant', 'content': [{'text': '{\n  "organization": "Western Dark Fired Tobacco Growers\' Association",\n  "address": "206 Maple Street P.O. Box 1056 Murray Kentucky 42071-1056",\n  "phone": "(502) 753-3341",\n  "fax": "(502) 753-0069/3342",\n  "date": "October 31, 1995",\n  "recipient": {\n    "name": "The Honorable Wendell H. Ford",\n    "title": "United States Senate",\n    "address": "Washington, D. C. 20510"\n  },\n  "sender": {\n    "name": "Will E. Clark",\n    "title": "General Manager"\n  },\n  "content": {\n    "opposition": "Strong... [truncated]'}]}}, 'stopReason': 'end_turn', 'usage': {'inputTokens': 2112, 'outputTokens': 326, 'totalTokens': 2438}, 'metrics': {'latencyMs': 5079}}
# INFO:idp_common.bedrock.client:Token Usage: {'inputTokens': 2112, 'outputTokens': 326, 'totalTokens': 2438}
# Extraction for section 1 completed in 7.15 seconds
#
# Processing section 2 (class: LAB SERVICES CONSISTENCY REPORT)
# INFO:idp_common.bedrock.client:Bedrock request attempt 1/7:
# INFO:idp_common.bedrock.client:  - model: us.amazon.nova-pro-v1:0
# INFO:idp_common.bedrock.client:  - inferenceConfig: {'temperature': 0.0, 'topP': 0.1}
# INFO:idp_common.bedrock.client:  - system: [{'text': 'You are a document assistant. Respond only with JSON. Never make up data.'}]
# INFO:idp_common.bedrock.client:  - messages: [{'role': 'user', 'content': [{'text': 'Extract information from the document and return as JSON. Document type: LAB SERVICES CONSISTENCY REPORT. Text: # LAB SERVICES CONSISTENCY REPORT \n\nDATE: 2/28/93\n TECHNICIAN: CC\n SHIFT: A\nTrial 8\n LINE: 2\n AREA: 52\nPRODUCT UNIT CODE:\n0728\n SAMPLE ID:\nstuff box 2\n REASON FOR REQUEST\ntest\n\nREQUESTED DELIVERY TIME:\n\nTIME SAMPLE RECEIVED:\n-\n TIME ANALYSIS COMPLETED:\n\nDATA COMMUNICATED TO\nGone\nAT 105\n\nPerson\nTime\n\nDRYING TIME\n\n\n\n\nA\tB\tC\tD\tE\tIN:\tOUT:\nSAMPLE &\tCONTAINER\tSAMPLE\tDILUTION\tDILUTED\nCONTAINER\tWEIGHT IN\tWEIGHT IN\tFACTOR\tSAMPLE\nWEIGHT IN\tGRAMS\tGRAMS\tWEIGHT IN\nGRAMS\t(A-B)\tGRAMS\nF\tG\tH\tI\n1159.3\t6\t6955. 8\tWEIGHT IN\tPAPER\tFILTER\tWEIGHT IN\tORAMS\tSAMPLE\tWEIGHT IN\tPAPER\tSAMPLE &\tH-P\t% CONSISTENCY\to\tx D 1 00\nORAMS\tGRAMS\nWET\tDRY\nAVERAGE 3.68\tCONSISTENCY\tSAMPLE #1 10\tSAMPLE #7 //\t2645\t2853\t84 568\t79.235\t3.366\t3123\t3.62\t3.64\n15\nSAMPLE $ 12\t2847\t89.776\t3.411\t3.77\nRANGE:\nMETER READING:\nCOMMENTS:\n\n\n\nACONSIST wis\n\n\n2030053328\n. Image: '}, {'image': '[image_data]'}, {'text': '.'}]}]
# INFO:idp_common.bedrock.client:  - additionalModelRequestFields: {'inferenceConfig': {'topK': 5}}
# INFO:idp_common.bedrock.client:Bedrock request successful after 1 attempts. Duration: 11.89s
# DEBUG:idp_common.bedrock.client:Response: {'ResponseMetadata': {'RequestId': 'ef96f5c6-8d61-4c31-bc5b-df217098a395', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Fri, 06 Jun 2025 20:54:02 GMT', 'content-type': 'application/json', 'content-length': '1326', 'connection': 'keep-alive', 'x-amzn-requestid': 'ef96f5c6-8d61-4c31-bc5b-df217098a395'}, 'RetryAttempts': 3}, 'output': {'message': {'role': 'assistant', 'content': [{'text': '{\n  "report_type": "LAB SERVICES CONSISTENCY REPORT",\n  "date": "7/28/93",\n  "technician": "CC",\n  "shift": "A",\n  "trial": 8,\n  "line": 2,\n  "area": 52,\n  "product_unit_code": "0728",\n  "sample_id": "stuff box 2",\n  "reason_for_request": "test",\n  "requested_delivery_time": "",\n  "time_sample_received": "-",\n  "time_analysis_completed": "",\n  "data_communicated_to": "Gone",\n  "at": "105",\n  "person": "",\n  "time": "",\n  "drying_time": {\n    "in": "",\n    "out": ""\n  },\n  "consistency_data": [\n ... [truncated]'}]}}, 'stopReason': 'end_turn', 'usage': {'inputTokens': 2043, 'outputTokens': 372, 'totalTokens': 2415}, 'metrics': {'latencyMs': 5730}}
# INFO:idp_common.bedrock.client:Token Usage: {'inputTokens': 2043, 'outputTokens': 372, 'totalTokens': 2415}
# Extraction for section 2 completed in 13.76 seconds
#
# Processing section 3 (class: Internal Communication)
# INFO:idp_common.bedrock.client:Bedrock request attempt 1/7:
# INFO:idp_common.bedrock.client:  - model: us.amazon.nova-pro-v1:0
# INFO:idp_common.bedrock.client:  - inferenceConfig: {'temperature': 0.0, 'topP': 0.1}
# INFO:idp_common.bedrock.client:  - system: [{'text': 'You are a document assistant. Respond only with JSON. Never make up data.'}]
# INFO:idp_common.bedrock.client:  - messages: [{'role': 'user', 'content': [{'text': "Extract information from the document and return as JSON. Document type: Internal Communication. Text: # Ashley Bratich \n\nFrom: Kelahan, Ben To: TI New York: 'TI Minnesota Co: Ashley Bratich (MSMAIL) Subject: FW: Morning Team Notes 4/20 Date: Saturday, April 18. 1998 2:09PM \n\nOriginal Message From: Byron Nelson (SMTP:bnelson@wka.com] Sent: Friday, April 17. 1998 5:25 PM To: Judy Albert: Carolyn: Jackie Cohen (AWMA): Frank: Goody; Henry: Hollant: Chris Holt; Hurst: Jim; Joe: John; Benjamin Kelahan: Cheryl Klein: Walt Klein: Lbeckwith; Rob Meyne: Mkatz; Morrow; Powers; Randy; Roger; Ron: Shorep; Steve Strawsburg: Suggsm; Matthew Tilley: whitey Co: Bob Fackler: Bob Stone Subject: Morning Team Notes 4/20 \n\nFalmouth MA - On 4/15, town meeting representatives defeated by a 84-77 vote a warrant article calling for a 100 percent ban on smoking in restaurants On 4/16, a motion to reconsider the vote was soundly rejected 104-49. The restaurant owner's moderate alternative was not considered because the town counsel found the article to be unconstitutional \n\nWaseca County MN - On 4/7 the county commissioners once again tabled consideration of a new tobacco retailing ordinance Waseca is the 11th Minnesota community to put the issue on hold. \n\nWadena County, MN - In mid-March the county commissioners tabled consideration of a new tobacco retailing ordinance until 4/23 At that time. they will take up a model ordinance that mirrors the state law. Bob Fackler requests calls to retailers to alert them to attend \n\nPage 1\n\n\nTI1716-0284\n. Image: "}, {'image': '[image_data]'}, {'text': '.'}]}]
# INFO:idp_common.bedrock.client:  - additionalModelRequestFields: {'inferenceConfig': {'topK': 5}}
# INFO:idp_common.bedrock.client:Bedrock request successful after 1 attempts. Duration: 16.42s
# DEBUG:idp_common.bedrock.client:Response: {'ResponseMetadata': {'RequestId': 'a3a0856b-8ac9-41f5-b34d-9f83824cc07f', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Fri, 06 Jun 2025 20:54:20 GMT', 'content-type': 'application/json', 'content-length': '2551', 'connection': 'keep-alive', 'x-amzn-requestid': 'a3a0856b-8ac9-41f5-b34d-9f83824cc07f'}, 'RetryAttempts': 4}, 'output': {'message': {'role': 'assistant', 'content': [{'text': '{\n  "document_type": "Internal Communication",\n  "from": "Kelahan, Ben",\n  "to": [\n    "TI New York",\n    "TI Minnesota",\n    "Ashley Bratich (MSMAIL)"\n  ],\n  "cc": [],\n  "subject": "FW: Morning Team Notes 4/20",\n  "date": "Saturday, April 18, 1998 2:09PM",\n  "original_message": {\n    "from": "Byron Nelson (SMTP:bnelson@wka.com)",\n    "sent": "Friday, April 17, 1998 5:25 PM",\n    "to": [\n      "Judy Albert",\n      "Carolyn",\n      "Jackie Cohen (AWMA)",\n      "Frank",\n      "Goody",\n      "Henry... [truncated]'}]}}, 'stopReason': 'end_turn', 'usage': {'inputTokens': 2053, 'outputTokens': 627, 'totalTokens': 2680}, 'metrics': {'latencyMs': 9017}}
# INFO:idp_common.bedrock.client:Token Usage: {'inputTokens': 2053, 'outputTokens': 627, 'totalTokens': 2680}
# Extraction for section 3 completed in 18.10 seconds
#
# Extraction for first 3 sections complete.

# %% [markdown]
# ## 8. Assess Extraction Confidence
#
# This is the new step that evaluates the confidence and accuracy of the extraction results by analyzing them against the source document.

# %%
# Create assessment service with Bedrock
assessment_service = assessment.AssessmentService(config=CONFIG)

print("\nAssessing extraction confidence for document sections...")

# Process each section that has extraction results
for section in document.sections[:n]:  
    if section.extraction_result_uri:
        print(f"\nAssessing section {section.section_id} (class: {section.classification})")
        
        # Assess the section
        start_time = time.time()
        document = assessment_service.process_document_section(
            document=document,
            section_id=section.section_id
        )
        assessment_time = time.time() - start_time
        print(f"Assessment for section {section.section_id} completed in {assessment_time:.2f} seconds")
    else:
        print(f"\nSkipping section {section.section_id} - no extraction results to assess")
        
print(f"\nAssessment for first {n} sections complete.")
# Out:
# INFO:idp_common.assessment.service:Initialized assessment service with model us.amazon.nova-pro-v1:0
# INFO:idp_common.assessment.service:Assessing 1 pages, class lobbying letter: 1-1
# Assessing extraction confidence for document sections...
#
# Assessing section 1 (class: lobbying letter)
# INFO:idp_common.assessment.service:Time taken to read extraction results: 0.08 seconds
# INFO:idp_common.assessment.service:Time taken to read text content: 0.08 seconds
# INFO:idp_common.assessment.service:Time taken to read images: 0.24 seconds
# INFO:idp_common.assessment.service:Time taken to read raw OCR results: 0.08 seconds
# INFO:idp_common.assessment.service:Assessing extraction confidence for lobbying letter document, section 1
# DEBUG:idp_common.bedrock.client:Found <<CACHEPOINT>> tags in text content: <background>
# You are an expert document analysis a...
# DEBUG:idp_common.bedrock.client:Split text into 2 parts at cachepoint tags
# DEBUG:idp_common.bedrock.client:Text part 1: 364 words
# DEBUG:idp_common.bedrock.client:Inserting cachePoint #1 after text part 1
# DEBUG:idp_common.bedrock.client:Text part 2: 325 words
# DEBUG:idp_common.bedrock.client:No cachepoint tags in image content, passing through unchanged
# DEBUG:idp_common.bedrock.client:No cachepoint tags in text content, passing through unchanged
# INFO:idp_common.bedrock.client:Processed content with 1 cachepoint insertions
# INFO:idp_common.bedrock.client:Applied cachePoint processing for supported model: us.amazon.nova-pro-v1:0
# INFO:idp_common.bedrock.client:Bedrock request attempt 1/7:
# INFO:idp_common.bedrock.client:  - model: us.amazon.nova-pro-v1:0
# INFO:idp_common.bedrock.client:  - inferenceConfig: {'temperature': 0.0, 'topP': 0.1, 'maxTokens': 4096}
# INFO:idp_common.bedrock.client:  - system: [{'text': 'You are a document analysis assessment expert. Your task is to evaluate the confidence and accuracy of extraction results by analyzing the source document evidence. Respond only with JSON containing confidence scores and reasoning for each extracted attribute.'}]
# INFO:idp_common.bedrock.client:  - messages: [{'role': 'user', 'content': [{'text': '<background>\nYou are an expert document analysis assessment system. Your task is to evaluate the confidence and accuracy of extraction results for a document of class lobbying letter.\n</background>\n\n<task>\nAnalyze the extraction results against the source document and provide confidence assessments for each extracted attribute. Consider factors such as:\n1. Text clarity and OCR quality in the source regions\n2. Alignment between extracted values and document content\n3. Presence of clear evidence supporting the extraction\n4. Potential ambiguity or uncertainty in the source material\n5. Completeness and accuracy of the extracted information\n</task>\n\n<assessment-guidelines>\nFor each attribute, provide:\n1. A confidence score between 0.0 and 1.0 where:\n   - 1.0 = Very high confidence, clear and unambiguous evidence\n   - 0.8-0.9 = High confidence, strong evidence with minor uncertainty\n   - 0.6-0.7 = Medium confidence, reasonable evidence but some ambiguity\n   - 0.4-0.5 = Low confidence, weak or unclear evidence\n   - 0.0-0.3 = Very low confidence, little to no supporting evidence\n\n2. A clear reason explaining the confidence score, including:\n   - What evidence supports or contradicts the extraction\n   - Any OCR quality issues that affect confidence\n   - Clarity of the source document in relevant areas\n   - Any ambiguity or uncertainty factors\n</assessment-guidelines>\n\n<extraction-results>\n{\n  "organization": "Western Dark Fired Tobacco Growers\' Association",\n  "address": "206 Maple Street P.O. Box 1056 Murray Kentucky 42071-1056",\n  "phone": "(502) 753-3341",\n  "fax": "(502) 753-0069/3342",\n  "date": "October 31, 1995",\n  "recipient": {\n    "name": "The Honorable Wendell H. Ford",\n    "title": "United States Senate",\n    "address": "Washington, D. C. 20510"\n  },\n  "sender": {\n    "name": "Will E. Clark",\n    "title": "General Manager"\n  },\n  "content": {\n    "opposition": "Strong opposition to the \'Commitment to our Children\' petition",\n    "arguments": [\n      "No one in the tobacco industry wants young people to consume tobacco products.",\n      "Age restriction laws are already in place in every state.",\n      "Better enforcement of existing laws is needed, not more bureaucracy.",\n      "FDA regulation would add another layer of government oversight, similar to USDA, EPA, and OSHA.",\n      "FDA regulation would be inefficient and create more bureaucracy.",\n      "FDA regulation would infringe on the First Amendment right to use a legal product."\n    ],\n    "request": "Urges Senator Ford to consider the consequences of the petition and prevent FDA from regulating tobacco."\n  }\n}\n</extraction-results>\n\n<attributes-definitions>\n\n</attributes-definitions>\n\n'}, {'cachePoint': {'type': 'default'}}, {'text': '\n\n<document-text>\n\n\nWESTERN DARK FIRED TOBACCO GROWERS\' ASSOCIATION \n\n206 Maple Street P.O. Box 1056 Murray Kentucky 42071-1056 \n\n(502) 753-3341 FAX (502) 753-0069/3342 \n\nOctober 31, 1995 \n\nThe Honorable Wendell H. Ford United States Senate Washington, D. C. 20510 \n\nDear Senator Ford: \n\nOn behalf of the Western Dark Fired Tobacco Growers\' Association and the 9,000 tobacco producers it represents, I an obligated to convey our strong opposition to the "Commitment to our Children\' petition being circulated by several Members of Congress. \n\nIn the tobacco industry, no one wants young people to consume tobacco products and age restriction laws are on the books in every state in the nation. We must take action to better enforce these laws, not create more bureaucracy. \n\ngovernment bureaucracy, thus destroying our family farms and There are those in our society who want to add inefficient hampering an adult\'s First Amendment right to the freedom of choice in using a legal product. \n\nYou may have been approached by those who say they are supporting Administration (FD ...
# INFO:idp_common.bedrock.client:  - additionalModelRequestFields: {'inferenceConfig': {'topK': 5}}
# INFO:idp_common.bedrock.client:Bedrock request successful after 1 attempts. Duration: 15.92s
# DEBUG:idp_common.bedrock.client:Response: {'ResponseMetadata': {'RequestId': 'f3eeb80d-d261-4287-b36d-21ca2217a8bf', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Fri, 06 Jun 2025 20:54:38 GMT', 'content-type': 'application/json', 'content-length': '3176', 'connection': 'keep-alive', 'x-amzn-requestid': 'f3eeb80d-d261-4287-b36d-21ca2217a8bf'}, 'RetryAttempts': 3}, 'output': {'message': {'role': 'assistant', 'content': [{'text': '```json\n{\n  "organization": {\n    "confidence_score": 0.99,\n    "confidence_reason": "Clear text evidence found in document header with very high OCR confidence (0.9935718536376953). Value matches exactly."\n  },\n  "address": {\n    "confidence_score": 0.85,\n    "confidence_reason": "Text evidence found in document header with high OCR confidence for most parts (ranging from 0.7776668548583984 to 0.9141302490234375). Value matches exactly."\n  },\n  "phone": {\n    "confidence_score": 0.86,\n    "conf... [truncated]'}]}}, 'stopReason': 'end_turn', 'usage': {'inputTokens': 4184, 'outputTokens': 869, 'totalTokens': 5742, 'cacheReadInputTokens': 0, 'cacheWriteInputTokens': 689}, 'metrics': {'latencyMs': 13111}}
# INFO:idp_common.bedrock.client:Token Usage: {'inputTokens': 4184, 'outputTokens': 869, 'totalTokens': 5742, 'cacheReadInputTokens': 0, 'cacheWriteInputTokens': 689}
# INFO:idp_common.assessment.service:Time taken for assessment: 16.93 seconds
# INFO:idp_common.assessment.service:Total assessment time for section 1: 17.70 seconds
# INFO:idp_common.assessment.service:Assessing 1 pages, class LAB SERVICES CONSISTENCY REPORT: 2-2
# Assessment for section 1 completed in 17.84 seconds
#
# Assessing section 2 (class: LAB SERVICES CONSISTENCY REPORT)
# INFO:idp_common.assessment.service:Time taken to read extraction results: 0.12 seconds
# INFO:idp_common.assessment.service:Time taken to read text content: 0.08 seconds
# INFO:idp_common.assessment.service:Time taken to read images: 0.32 seconds
# INFO:idp_common.assessment.service:Time taken to read raw OCR results: 0.08 seconds
# INFO:idp_common.assessment.service:Assessing extraction confidence for LAB SERVICES CONSISTENCY REPORT document, section 2
# DEBUG:idp_common.bedrock.client:Found <<CACHEPOINT>> tags in text content: <background>
# You are an expert document analysis a...
# DEBUG:idp_common.bedrock.client:Split text into 2 parts at cachepoint tags
# DEBUG:idp_common.bedrock.client:Text part 1: 303 words
# DEBUG:idp_common.bedrock.client:Inserting cachePoint #1 after text part 1
# DEBUG:idp_common.bedrock.client:Text part 2: 148 words
# DEBUG:idp_common.bedrock.client:No cachepoint tags in image content, passing through unchanged
# DEBUG:idp_common.bedrock.client:No cachepoint tags in text content, passing through unchanged
# INFO:idp_common.bedrock.client:Processed content with 1 cachepoint insertions
# INFO:idp_common.bedrock.client:Applied cachePoint processing for supported model: us.amazon.nova-pro-v1:0
# INFO:idp_common.bedrock.client:Bedrock request attempt 1/7:
# INFO:idp_common.bedrock.client:  - model: us.amazon.nova-pro-v1:0
# INFO:idp_common.bedrock.client:  - inferenceConfig: {'temperature': 0.0, 'topP': 0.1, 'maxTokens': 4096}
# INFO:idp_common.bedrock.client:  - system: [{'text': 'You are a document analysis assessment expert. Your task is to evaluate the confidence and accuracy of extraction results by analyzing the source document evidence. Respond only with JSON containing confidence scores and reasoning for each extracted attribute.'}]
# INFO:idp_common.bedrock.client:  - messages: [{'role': 'user', 'content': [{'text': '<background>\nYou are an expert document analysis assessment system. Your task is to evaluate the confidence and accuracy of extraction results for a document of class LAB SERVICES CONSISTENCY REPORT.\n</background>\n\n<task>\nAnalyze the extraction results against the source document and provide confidence assessments for each extracted attribute. Consider factors such as:\n1. Text clarity and OCR quality in the source regions\n2. Alignment between extracted values and document content\n3. Presence of clear evidence supporting the extraction\n4. Potential ambiguity or uncertainty in the source material\n5. Completeness and accuracy of the extracted information\n</task>\n\n<assessment-guidelines>\nFor each attribute, provide:\n1. A confidence score between 0.0 and 1.0 where:\n   - 1.0 = Very high confidence, clear and unambiguous evidence\n   - 0.8-0.9 = High confidence, strong evidence with minor uncertainty\n   - 0.6-0.7 = Medium confidence, reasonable evidence but some ambiguity\n   - 0.4-0.5 = Low confidence, weak or unclear evidence\n   - 0.0-0.3 = Very low confidence, little to no supporting evidence\n\n2. A clear reason explaining the confidence score, including:\n   - What evidence supports or contradicts the extraction\n   - Any OCR quality issues that affect confidence\n   - Clarity of the source document in relevant areas\n   - Any ambiguity or uncertainty factors\n</assessment-guidelines>\n\n<extraction-results>\n{\n  "report_type": "LAB SERVICES CONSISTENCY REPORT",\n  "date": "7/28/93",\n  "technician": "CC",\n  "shift": "A",\n  "trial": 8,\n  "line": 2,\n  "area": 52,\n  "product_unit_code": "0728",\n  "sample_id": "stuff box 2",\n  "reason_for_request": "test",\n  "requested_delivery_time": "",\n  "time_sample_received": "-",\n  "time_analysis_completed": "",\n  "data_communicated_to": "Gone",\n  "at": "105",\n  "person": "",\n  "time": "",\n  "drying_time": {\n    "in": "",\n    "out": ""\n  },\n  "consistency_data": [\n    {\n      "sample": "SAMPLE #1 10",\n      "wet": "2.833",\n      "dry": "84.565",\n      "% consistency": "3.366"\n    },\n    {\n      "sample": "SAMPLE #7 11",\n      "wet": "2.645",\n      "dry": "79.235",\n      "% consistency": "3.62"\n    },\n    {\n      "sample": "SAMPLE # 12",\n      "wet": "2.847",\n      "dry": "89.776",\n      "% consistency": "3.411"\n    }\n  ],\n  "average_consistency": "3.68",\n  "range": "15",\n  "meter_reading": "",\n  "comments": ""\n}\n</extraction-results>\n\n<attributes-definitions>\n\n</attributes-definitions>\n\n'}, {'cachePoint': {'type': 'default'}}, {'text': '\n\n<document-text>\n# LAB SERVICES CONSISTENCY REPORT \n\nDATE: 2/28/93\n TECHNICIAN: CC\n SHIFT: A\nTrial 8\n LINE: 2\n AREA: 52\nPRODUCT UNIT CODE:\n0728\n SAMPLE ID:\nstuff box 2\n REASON FOR REQUEST\ntest\n\nREQUESTED DELIVERY TIME:\n\nTIME SAMPLE RECEIVED:\n-\n TIME ANALYSIS COMPLETED:\n\nDATA COMMUNICATED TO\nGone\nAT 105\n\nPerson\nTime\n\nDRYING TIME\n\n\n\n\nA\tB\tC\tD\tE\tIN:\tOUT:\nSAMPLE &\tCONTAINER\tSAMPLE\tDILUTION\tDILUTED\nCONTAINER\tWEIGHT IN\tWEIGHT IN\tFACTOR\tSAMPLE\nWEIGHT IN\tGRAMS\tGRAMS\tWEIGHT IN\nGRAMS\t(A-B)\tGRAMS\nF\tG\tH\tI\n1159.3\t6\t6955. 8\tWEIGHT IN\tPAPER\tFILTER\tWEIGHT IN\tORAMS\tSAMPLE\tWEIGHT IN\tPAPER\tSAMPLE &\tH-P\t% CONSISTENCY\to\tx D 1 00\nORAMS\tGRAMS\nWET\tDRY\nAVERAGE 3.68\tCONSISTENCY\tSAMPLE #1 10\tSAMPLE #7 //\t2645\t2853\t84 568\t79.235\t3.366\t3123\t3.62\t3.64\n15\nSAMPLE $ 12\t2847\t89.776\t3.411\t3.77\nRANGE:\nMETER READING:\nCOMMENTS:\n\n\n\nACONSIST wis\n\n\n2030053328\n\n</document-text>\n\n<document-image>\n'}, {'image': '[image_data]'}, {'text': '\n</document-image>\n\n<ocr-raw-results>\n\n--- Page 2 Text Confidence Data ---\n{\n  "page_count": 1,\n  "text_blocks": [\n    {\n      "text": "LAB SERVICES CONSISTENCY REPORT",\n      "confidence": 99.86489868164062\n    },\n    {\n      "text": "DATE: 2/28/93",\n      "confidence": 84.54127502441406\n ...
# INFO:idp_common.bedrock.client:  - additionalModelRequestFields: {'inferenceConfig': {'topK': 5}}
# INFO:idp_common.bedrock.client:Bedrock request successful after 1 attempts. Duration: 23.99s
# DEBUG:idp_common.bedrock.client:Response: {'ResponseMetadata': {'RequestId': '6d69778a-d496-49c1-8426-477f7d7e085c', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Fri, 06 Jun 2025 20:55:04 GMT', 'content-type': 'application/json', 'content-length': '5363', 'connection': 'keep-alive', 'x-amzn-requestid': '6d69778a-d496-49c1-8426-477f7d7e085c'}, 'RetryAttempts': 0}, 'output': {'message': {'role': 'assistant', 'content': [{'text': '```json\n{\n  "report_type": {\n    "confidence_score": 1.0,\n    "confidence_reason": "Clear and unambiguous evidence in the document header with very high OCR confidence (0.9986489868164062)."\n  },\n  "date": {\n    "confidence_score": 0.4,\n    "confidence_reason": "Mismatch between extracted date \'7/28/93\' and document date \'2/28/93\'. OCR confidence is moderate (0.8454127502441406), indicating potential error."\n  },\n  "technician": {\n    "confidence_score": 0.8,\n    "confidence_reason": "Extracted ... [truncated]'}]}}, 'stopReason': 'end_turn', 'usage': {'inputTokens': 5573, 'outputTokens': 1594, 'totalTokens': 7908, 'cacheReadInputTokens': 0, 'cacheWriteInputTokens': 741}, 'metrics': {'latencyMs': 23795}}
# INFO:idp_common.bedrock.client:Token Usage: {'inputTokens': 5573, 'outputTokens': 1594, 'totalTokens': 7908, 'cacheReadInputTokens': 0, 'cacheWriteInputTokens': 741}
# INFO:idp_common.assessment.service:Time taken for assessment: 25.12 seconds
# INFO:idp_common.assessment.service:Total assessment time for section 2: 26.01 seconds
# INFO:idp_common.assessment.service:Assessing 1 pages, class Internal Communication: 3-3
# Assessment for section 2 completed in 26.14 seconds
#
# Assessing section 3 (class: Internal Communication)
# INFO:idp_common.assessment.service:Time taken to read extraction results: 0.08 seconds
# INFO:idp_common.assessment.service:Time taken to read text content: 0.08 seconds
# INFO:idp_common.assessment.service:Time taken to read images: 0.15 seconds
# INFO:idp_common.assessment.service:Time taken to read raw OCR results: 0.08 seconds
# INFO:idp_common.assessment.service:Assessing extraction confidence for Internal Communication document, section 3
# DEBUG:idp_common.bedrock.client:Found <<CACHEPOINT>> tags in text content: <background>
# You are an expert document analysis a...
# DEBUG:idp_common.bedrock.client:Split text into 2 parts at cachepoint tags
# DEBUG:idp_common.bedrock.client:Text part 1: 457 words
# DEBUG:idp_common.bedrock.client:Inserting cachePoint #1 after text part 1
# DEBUG:idp_common.bedrock.client:Text part 2: 228 words
# DEBUG:idp_common.bedrock.client:No cachepoint tags in image content, passing through unchanged
# DEBUG:idp_common.bedrock.client:No cachepoint tags in text content, passing through unchanged
# INFO:idp_common.bedrock.client:Processed content with 1 cachepoint insertions
# INFO:idp_common.bedrock.client:Applied cachePoint processing for supported model: us.amazon.nova-pro-v1:0
# INFO:idp_common.bedrock.client:Bedrock request attempt 1/7:
# INFO:idp_common.bedrock.client:  - model: us.amazon.nova-pro-v1:0
# INFO:idp_common.bedrock.client:  - inferenceConfig: {'temperature': 0.0, 'topP': 0.1, 'maxTokens': 4096}
# INFO:idp_common.bedrock.client:  - system: [{'text': 'You are a document analysis assessment expert. Your task is to evaluate the confidence and accuracy of extraction results by analyzing the source document evidence. Respond only with JSON containing confidence scores and reasoning for each extracted attribute.'}]
# INFO:idp_common.bedrock.client:  - messages: [{'role': 'user', 'content': [{'text': '<background>\nYou are an expert document analysis assessment system. Your task is to evaluate the confidence and accuracy of extraction results for a document of class Internal Communication.\n</background>\n\n<task>\nAnalyze the extraction results against the source document and provide confidence assessments for each extracted attribute. Consider factors such as:\n1. Text clarity and OCR quality in the source regions\n2. Alignment between extracted values and document content\n3. Presence of clear evidence supporting the extraction\n4. Potential ambiguity or uncertainty in the source material\n5. Completeness and accuracy of the extracted information\n</task>\n\n<assessment-guidelines>\nFor each attribute, provide:\n1. A confidence score between 0.0 and 1.0 where:\n   - 1.0 = Very high confidence, clear and unambiguous evidence\n   - 0.8-0.9 = High confidence, strong evidence with minor uncertainty\n   - 0.6-0.7 = Medium confidence, reasonable evidence but some ambiguity\n   - 0.4-0.5 = Low confidence, weak or unclear evidence\n   - 0.0-0.3 = Very low confidence, little to no supporting evidence\n\n2. A clear reason explaining the confidence score, including:\n   - What evidence supports or contradicts the extraction\n   - Any OCR quality issues that affect confidence\n   - Clarity of the source document in relevant areas\n   - Any ambiguity or uncertainty factors\n</assessment-guidelines>\n\n<extraction-results>\n{\n  "document_type": "Internal Communication",\n  "from": "Kelahan, Ben",\n  "to": [\n    "TI New York",\n    "TI Minnesota",\n    "Ashley Bratich (MSMAIL)"\n  ],\n  "cc": [],\n  "subject": "FW: Morning Team Notes 4/20",\n  "date": "Saturday, April 18, 1998 2:09PM",\n  "original_message": {\n    "from": "Byron Nelson (SMTP:bnelson@wka.com)",\n    "sent": "Friday, April 17, 1998 5:25 PM",\n    "to": [\n      "Judy Albert",\n      "Carolyn",\n      "Jackie Cohen (AWMA)",\n      "Frank",\n      "Goody",\n      "Henry",\n      "Hollant",\n      "Chris Holt",\n      "Hurst",\n      "Jim",\n      "Joe",\n      "John",\n      "Benjamin Kelahan",\n      "Cheryl Klein",\n      "Walt Klein",\n      "Lbeckwith",\n      "Rob Meyne",\n      "Mkatz",\n      "Morrow",\n      "Powers",\n      "Randy",\n      "Roger",\n      "Ron",\n      "Shorep",\n      "Steve Strawsburg",\n      "Suggsm",\n      "Matthew Tilley",\n      "whitey"\n    ],\n    "cc": [\n      "Bob Fackler",\n      "Bob Stone"\n    ],\n    "subject": "Morning Team Notes 4/20"\n  },\n  "content": [\n    {\n      "location": "Falmouth MA",\n      "event": "Town meeting representatives defeated a warrant article calling for a 100 percent ban on smoking in restaurants by a 84-77 vote.",\n      "date": "4/15"\n    },\n    {\n      "location": "Falmouth MA",\n      "event": "A motion to reconsider the vote was soundly rejected 104-49. The restaurant owner\'s moderate alternative was not considered because the town counsel found the article to be unconstitutional.",\n      "date": "4/16"\n    },\n    {\n      "location": "Waseca County MN",\n      "event": "The county commissioners once again tabled consideration of a new tobacco retailing ordinance. Waseca is the 11th Minnesota community to put the issue on hold.",\n      "date": "4/7"\n    },\n    {\n      "location": "Wadena County, MN",\n      "event": "The county commissioners tabled consideration of a new tobacco retailing ordinance until 4/23. At that time, they will take up a model ordinance that mirrors the state law. Bob Fackler requests calls to retailers to alert them to attend.",\n      "date": "mid-March"\n    }\n  ],\n  "image": "TI1716-0284",\n  "page": 1\n}\n</extraction-results>\n\n<attributes-definitions>\n\n</attributes-definitions>\n\n'}, {'cachePoint': {'type': 'default'}}, {'text': "\n\n<document-text>\n# Ashley Bratich \n\nFrom: Kelahan, Ben To: TI New York: 'TI Minnesota Co: Ashley Bratich (MSMAIL) Subject: FW: Mo ...
# INFO:idp_common.bedrock.client:  - additionalModelRequestFields: {'inferenceConfig': {'topK': 5}}
# INFO:idp_common.bedrock.client:Bedrock request successful after 1 attempts. Duration: 13.26s
# DEBUG:idp_common.bedrock.client:Response: {'ResponseMetadata': {'RequestId': '48fadeea-5769-4381-b1b8-501afb63d99c', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Fri, 06 Jun 2025 20:55:20 GMT', 'content-type': 'application/json', 'content-length': '3423', 'connection': 'keep-alive', 'x-amzn-requestid': '48fadeea-5769-4381-b1b8-501afb63d99c'}, 'RetryAttempts': 0}, 'output': {'message': {'role': 'assistant', 'content': [{'text': '```json\n{\n  "document_type": {\n    "confidence_score": 1.0,\n    "confidence_reason": "The document type is explicitly stated as \'Internal Communication\', which matches the extracted value."\n  },\n  "from": {\n    "confidence_score": 0.9,\n    "confidence_reason": "The \'from\' field is clearly stated as \'Kelahan, Ben\' in the document with high OCR confidence (0.9085)."\n  },\n  "to": {\n    "confidence_score": 0.6,\n    "confidence_reason": "The \'to\' field includes \'TI New York\' and \'TI Minnesota\', which... [truncated]'}]}}, 'stopReason': 'end_turn', 'usage': {'inputTokens': 3865, 'outputTokens': 878, 'totalTokens': 5733, 'cacheReadInputTokens': 0, 'cacheWriteInputTokens': 990}, 'metrics': {'latencyMs': 13071}}
# INFO:idp_common.bedrock.client:Token Usage: {'inputTokens': 3865, 'outputTokens': 878, 'totalTokens': 5733, 'cacheReadInputTokens': 0, 'cacheWriteInputTokens': 990}
# INFO:idp_common.assessment.service:Time taken for assessment: 14.25 seconds
# INFO:idp_common.assessment.service:Total assessment time for section 3: 14.96 seconds
# Assessment for section 3 completed in 15.10 seconds
#
# Assessment for first 3 sections complete.

# %% [markdown]
# ## 9. Display Assessment Results
#
# Let's examine the assessment results that have been added to the extraction results.

# %%
print("\nAssessment Results:")
print("===================\n")

for section in document.sections[:n]:
    if section.extraction_result_uri:
        print(f"Section {section.section_id} ({section.classification}):")
        
        # Load the updated extraction results with assessment
        extraction_data = load_json_from_s3(section.extraction_result_uri)
        
        # Display the inference results
        print(f"  Extraction Results:")
        inference_result = extraction_data.get('inference_result', {})
        for attr_name, attr_value in inference_result.items():
            print(f"    {attr_name}: {attr_value}")
        
        # Display the assessment results
        explainability_info = extraction_data.get('explainability_info', [])
        if explainability_info:
            print(f"  Assessment Results:")
            for attr_name, assessment in explainability_info[0].items():
                confidence_score = assessment.get('confidence_score', 'N/A')
                confidence_reason = assessment.get('confidence_reason', 'N/A')
                print(f"    {attr_name}:")
                print(f"      Confidence Score: {confidence_score}")
                print(f"      Reason: {confidence_reason}")
        else:
            print(f"  No assessment results found")
        
        print()
# Out:
# Assessment Results:
# ===================
#
# Section 1 (lobbying letter):
#   Extraction Results:
#     organization: Western Dark Fired Tobacco Growers' Association
#     address: 206 Maple Street P.O. Box 1056 Murray Kentucky 42071-1056
#     phone: (502) 753-3341
#     fax: (502) 753-0069/3342
#     date: October 31, 1995
#     recipient: {'name': 'The Honorable Wendell H. Ford', 'title': 'United States Senate', 'address': 'Washington, D. C. 20510'}
#     sender: {'name': 'Will E. Clark', 'title': 'General Manager'}
#     content: {'opposition': "Strong opposition to the 'Commitment to our Children' petition", 'arguments': ['No one in the tobacco industry wants young people to consume tobacco products.', 'Age restriction laws are already in place in every state.', 'Better enforcement of existing laws is needed, not more bureaucracy.', 'FDA regulation would add another layer of government oversight, similar to USDA, EPA, and OSHA.', 'FDA regulation would be inefficient and create more bureaucracy.', 'FDA regulation would infringe on the First Amendment right to use a legal product.'], 'request': 'Urges Senator Ford to consider the consequences of the petition and prevent FDA from regulating tobacco.'}
#   Assessment Results:
#     organization:
#       Confidence Score: 0.99
#       Reason: Clear text evidence found in document header with very high OCR confidence (0.9935718536376953). Value matches exactly.
#     address:
#       Confidence Score: 0.85
#       Reason: Text evidence found in document header with high OCR confidence for most parts (ranging from 0.7776668548583984 to 0.9141302490234375). Value matches exactly.
#     phone:
#       Confidence Score: 0.86
#       Reason: Text evidence found in document header with high OCR confidence (0.8616661071777344). Value matches exactly.
#     fax:
#       Confidence Score: 0.86
#       Reason: Text evidence found in document header with high OCR confidence (0.8624977111816406). Value matches exactly.
#     date:
#       Confidence Score: 0.82
#       Reason: Text evidence found in document header with moderate OCR confidence (0.8186568450927734). Value matches exactly.
#     recipient:
#       Confidence Score: N/A
#       Reason: N/A
#     sender:
#       Confidence Score: N/A
#       Reason: N/A
#     content:
#       Confidence Score: N/A
#       Reason: N/A
#
# Section 2 (LAB SERVICES CONSISTENCY REPORT):
#   Extraction Results:
#     report_type: LAB SERVICES CONSISTENCY REPORT
#     date: 7/28/93
#     technician: CC
#     shift: A
#     trial: 8
#     line: 2
#     area: 52
#     product_unit_code: 0728
#     sample_id: stuff box 2
#     reason_for_request: test
#     requested_delivery_time:
#     time_sample_received: -
#     time_analysis_completed:
#     data_communicated_to: Gone
#     at: 105
#     person:
#     time:
#     drying_time: {'in': '', 'out': ''}
#     consistency_data: [{'sample': 'SAMPLE #1 10', 'wet': '2.833', 'dry': '84.565', '% consistency': '3.366'}, {'sample': 'SAMPLE #7 11', 'wet': '2.645', 'dry': '79.235', '% consistency': '3.62'}, {'sample': 'SAMPLE # 12', 'wet': '2.847', 'dry': '89.776', '% consistency': '3.411'}]
#     average_consistency: 3.68
#     range: 15
#     meter_reading:
#     comments:
#   Assessment Results:
#     report_type:
#       Confidence Score: 1.0
#       Reason: Clear and unambiguous evidence in the document header with very high OCR confidence (0.9986489868164062).
#     date:
#       Confidence Score: 0.4
#       Reason: Mismatch between extracted date '7/28/93' and document date '2/28/93'. OCR confidence is moderate (0.8454127502441406), indicating potential error.
#     technician:
#       Confidence Score: 0.8
#       Reason: Extracted value 'CC' matches document text. OCR confidence is moderate (0.729090576171875), but clear evidence supports extraction.
#     shift:
#       Confidence Score: 0.9
#       Reason: Extracted value 'A' matches document text with high OCR confidence (0.9866841888427734).
#     trial:
#       Confidence Score: 1.0
#       Reason: Extracted value '8' matches document text with very high OCR confidence (0.9986919403076172).
#     line:
#       Confidence Score: 0.9
#       Reason: Extracted value '2' matches document text with high OCR confidence (0.9582356262207031).
#     area:
#       Confidence Score: 0.9
#       Reason: Extracted value '52' matches document text with high OCR confidence (0.9879305267333984).
#     product_unit_code:
#       Confidence Score: 0.7
#       Reason: Extracted value '0728' matches document text, but OCR confidence is moderate (0.6746604919433594), indicating some uncertainty.
#     sample_id:
#       Confidence Score: 0.7
#       Reason: Extracted value 'stuff box 2' matches document text with moderate OCR confidence (0.7057594299316406).
#     reason_for_request:
#       Confidence Score: 1.0
#       Reason: Extracted value 'test' matches document text with very high OCR confidence (0.999342269897461).
#     requested_delivery_time:
#       Confidence Score: 0.5
#       Reason: Extracted value is empty, and document shows a blank field. OCR confidence is high (0.9749275207519531) for the field label, but no value is present.
#     time_sample_received:
#       Confidence Score: 0.9
#       Reason: Extracted value '-' matches document text with high OCR confidence (0.9653641510009766).
#     time_analysis_completed:
#       Confidence Score: 0.5
#       Reason: Extracted value is empty, and document shows a blank field. OCR confidence is high (0.9849092102050781) for the field label, but no value is present.
#     data_communicated_to:
#       Confidence Score: 0.6
#       Reason: Extracted value 'Gone' has low OCR confidence (0.549041748046875), indicating some uncertainty.
#     at:
#       Confidence Score: 0.7
#       Reason: Extracted value '105' matches document text with moderate OCR confidence (0.701950912475586).
#     person:
#       Confidence Score: 0.5
#       Reason: Extracted value is empty, and document shows a blank field. OCR confidence is very high (0.9990739440917969) for the field label 'Person', but no value is present.
#     time:
#       Confidence Score: 0.5
#       Reason: Extracted value is empty, and document shows a blank field. OCR confidence is very high (0.9993097686767578) for the field label 'Time', but no value is present.
#     drying_time:
#       Confidence Score: 0.5
#       Reason: Extracted values are empty, and document shows blank fields for 'IN' and 'OUT'. OCR confidence is very high for the field labels, but no values are present.
#     consistency_data:
#       Confidence Score: 0.8
#       Reason: Extracted values mostly match document text, but some values have moderate to low OCR confidence, indicating some uncertainty. For example, 'wet' and 'dry' values for 'SAMPLE #7 11' have OCR confidences of 0.6653099060058594 and 0.970545425415039 respectively.
#     average_consistency:
#       Confidence Score: 0.8
#       Reason: Extracted value '3.68' matches document text with moderate OCR confidence (0.8003067016601562).
#     range:
#       Confidence Score: 0.6
#       Reason: Extracted value '15' matches document text, but OCR confidence is low (0.6017141342163086), indicating some uncertainty.
#     meter_reading:
#       Confidence Score: 0.5
#       Reason: Extracted value is empty, and document shows a blank field. OCR confidence is moderate (0.8183063507080078) for the field label, but no value is present.
#     comments:
#       Confidence Score: 0.5
#       Reason: Extracted value is empty, and document shows a blank field. OCR confidence is moderate (0.8728858184814453) for the field label, but no value is present.
#
# Section 3 (Internal Communication):
#   Extraction Results:
#     document_type: Internal Communication
#     from: Kelahan, Ben
#     to: ['TI New York', 'TI Minnesota', 'Ashley Bratich (MSMAIL)']
#     cc: []
#     subject: FW: Morning Team Notes 4/20
#     date: Saturday, April 18, 1998 2:09PM
#     original_message: {'from': 'Byron Nelson (SMTP:bnelson@wka.com)', 'sent': 'Friday, April 17, 1998 5:25 PM', 'to': ['Judy Albert', 'Carolyn', 'Jackie Cohen (AWMA)', 'Frank', 'Goody', 'Henry', 'Hollant', 'Chris Holt', 'Hurst', 'Jim', 'Joe', 'John', 'Benjamin Kelahan', 'Cheryl Klein', 'Walt Klein', 'Lbeckwith', 'Rob Meyne', 'Mkatz', 'Morrow', 'Powers', 'Randy', 'Roger', 'Ron', 'Shorep', 'Steve Strawsburg', 'Suggsm', 'Matthew Tilley', 'whitey'], 'cc': ['Bob Fackler', 'Bob Stone'], 'subject': 'Morning Team Notes 4/20'}
#     content: [{'location': 'Falmouth MA', 'event': 'Town meeting representatives defeated a warrant article calling for a 100 percent ban on smoking in restaurants by a 84-77 vote.', 'date': '4/15'}, {'location': 'Falmouth MA', 'event': "A motion to reconsider the vote was soundly rejected 104-49. The restaurant owner's moderate alternative was not considered because the town counsel found the article to be unconstitutional.", 'date': '4/16'}, {'location': 'Waseca County MN', 'event': 'The county commissioners once again tabled consideration of a new tobacco retailing ordinance. Waseca is the 11th Minnesota community to put the issue on hold.', 'date': '4/7'}, {'location': 'Wadena County, MN', 'event': 'The county commissioners tabled consideration of a new tobacco retailing ordinance until 4/23. At that time, they will take up a model ordinance that mirrors the state law. Bob Fackler requests calls to retailers to alert them to attend.', 'date': 'mid-March'}]
#     image: TI1716-0284
#     page: 1
#   Assessment Results:
#     document_type:
#       Confidence Score: 1.0
#       Reason: The document type is explicitly stated as 'Internal Communication', which matches the extracted value.
#     from:
#       Confidence Score: 0.9
#       Reason: The 'from' field is clearly stated as 'Kelahan, Ben' in the document with high OCR confidence (0.9085).
#     to:
#       Confidence Score: 0.6
#       Reason: The 'to' field includes 'TI New York' and 'TI Minnesota', which have lower OCR confidence (0.5879) and are somewhat ambiguous due to formatting issues. 'Ashley Bratich (MSMAIL)' has higher confidence (0.9402).
#     cc:
#       Confidence Score: 0.8
#       Reason: The 'cc' field is correctly identified as empty, supported by the document text which does not list any 'cc' recipients.
#     subject:
#       Confidence Score: 0.95
#       Reason: The 'subject' field matches exactly with the document text 'FW: Morning Team Notes 4/20', with high OCR confidence (0.9843).
#     date:
#       Confidence Score: 0.9
#       Reason: The 'date' field is clearly stated as 'Saturday, April 18, 1998 2:09PM' in the document with high OCR confidence (0.9195).
#     original_message:
#       Confidence Score: N/A
#       Reason: N/A
#     content:
#       Confidence Score: 0.9
#       Reason: The content items are clearly described in the document with high OCR confidence across the text blocks, though some regions have lower confidence (e.g., 0.8759 for Waseca County MN).
#     image:
#       Confidence Score: 0.8
#       Reason: The image reference 'TI1716-0284' is correctly identified, though with moderate OCR confidence (0.8246).
#     page:
#       Confidence Score: 1.0
#       Reason: The page number is clearly stated as '1' in the document with high OCR confidence (0.9709).

# %% [markdown]
# ## 10. Final Document Status Summary

# %%
# Update document status to COMPLETED
document.status = Status.COMPLETED

# Display final document state
print("Final Document State:")
print(f"Document ID: {document.id}")
print(f"Status: {document.status.value}")
print(f"Number of pages: {document.num_pages}")
print(f"Number of sections: {len(document.sections)}")

print("\n=== Assessment Feature Summary ===")
print("✅ OCR Processing - Convert PDF to text and images")
print("✅ Document Classification - Identify document types")
print("✅ Information Extraction - Extract structured data")
print("✅ Assessment - Evaluate extraction confidence")
print("\nThe assessment feature provides:")
print("- Confidence scores (0.0 to 1.0) for each extracted attribute")
print("- Detailed reasoning explaining the confidence level")
print("- Analysis of OCR quality and document clarity")
print("- Identification of ambiguous or uncertain extractions")
print("- Integration with existing extraction results")
# Out:
# Final Document State:
# Document ID: rvl-cdip-package-assessment
# Status: COMPLETED
# Number of pages: 10
# Number of sections: 10
#
# === Assessment Feature Summary ===
# ✅ OCR Processing - Convert PDF to text and images
# ✅ Document Classification - Identify document types
# ✅ Information Extraction - Extract structured data
# ✅ Assessment - Evaluate extraction confidence
#
# The assessment feature provides:
# - Confidence scores (0.0 to 1.0) for each extracted attribute
# - Detailed reasoning explaining the confidence level
# - Analysis of OCR quality and document clarity
# - Identification of ambiguous or uncertain extractions
# - Integration with existing extraction results

# %% [markdown]
# ## Conclusion
#
# This notebook demonstrates the enhanced end-to-end processing flow with the new **Assessment Service**:
#
# 1. **Document Creation** - Initialize a Document object with input/output locations
# 2. **OCR Processing** - Convert PDF to text using AWS Textract via OcrService
# 3. **Classification** - Identify document types and sections using Bedrock via ClassificationService
# 4. **Extraction** - Extract structured information using Bedrock via ExtractionService
# 5. **Assessment** - Evaluate extraction confidence using Bedrock via AssessmentService ✨ **NEW**
# 6. **Document Model** - Document object is consistently used between all services
# 7. **Result Storage** - Assessment results are stored alongside extraction results in S3
#
# ### Key Benefits of the Assessment Service:
#
# 1. **Explainability** - Provides confidence scores and reasoning for each extracted attribute
# 2. **Quality Control** - Identifies extractions that may need human review
# 3. **OCR Analysis** - Considers OCR quality and document clarity in confidence scoring
# 4. **Integration** - Seamlessly integrates with existing extraction workflows
# 5. **Flexibility** - Configurable prompts and models for different assessment strategies
# 6. **Multimodal** - Uses both text and image content for comprehensive assessment
#
# ### Assessment Output Structure:
#
# The assessment service appends `explainability_info` to existing extraction results:
#
# ```json
# {
#   "document_class": {"type": "letter"},
#   "inference_result": {
#     "sender_name": "John Doe",
#     "sender_address": "123 Main St"
#   },
#   "explainability_info": {
#     "sender_name": {
#       "confidence_score": 0.95,
#       "confidence_reason": "Clear text found in document header with high OCR confidence"
#     },
#     "sender_address": {
#       "confidence_score": 0.75,
#       "confidence_reason": "Address partially visible but some characters unclear"
#     }
#   },
#   "metadata": {
#     "extraction_time_seconds": 2.3,
#     "assessment_time_seconds": 1.8
#   }
# }
# ```
#
# This assessment capability enables more robust document processing workflows with built-in quality control and explainability features.
