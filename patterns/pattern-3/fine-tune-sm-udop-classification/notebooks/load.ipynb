# %%
import torch
import argparse
import json
import os
import tarfile
import lightning.pytorch as pl
from train import UDOPModel
from train import ClassificationDataset
from datasets import load_dataset
from transformers import AutoProcessor
from lightning.pytorch.callbacks import ModelCheckpoint
from lightning.pytorch.callbacks.early_stopping import EarlyStopping
from torch.utils.data import DataLoader
from sklearn.metrics import classification_report
# Out:
# Requirement already satisfied: transformers==4.43.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (4.43.0)
# Requirement already satisfied: filelock in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from transformers==4.43.0) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from transformers==4.43.0) (0.27.1)
# Requirement already satisfied: numpy>=1.17 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from transformers==4.43.0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from transformers==4.43.0) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from transformers==4.43.0) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from transformers==4.43.0) (2024.11.6)
# Requirement already satisfied: requests in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from transformers==4.43.0) (2.32.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from transformers==4.43.0) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from transformers==4.43.0) (0.5.2)
# Requirement already satisfied: tqdm>=4.27 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from transformers==4.43.0) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.43.0) (2024.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.43.0) (4.12.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from packaging>=20.0->transformers==4.43.0) (3.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from requests->transformers==4.43.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from requests->transformers==4.43.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from requests->transformers==4.43.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from requests->transformers==4.43.0) (2024.12.14)
# Requirement already satisfied: lightning in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (2.5.0.post0)
# Requirement already satisfied: PyYAML<8.0,>=5.4 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from lightning) (6.0.2)
# Requirement already satisfied: fsspec<2026.0,>=2022.5.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning) (2024.9.0)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from lightning) (0.11.9)
# Requirement already satisfied: packaging<25.0,>=20.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from lightning) (21.3)
# Requirement already satisfied: torch<4.0,>=2.1.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from lightning) (2.2.2)
# Requirement already satisfied: torchmetrics<3.0,>=0.7.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from lightning) (1.6.1)
# Requirement already satisfied: tqdm<6.0,>=4.57.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from lightning) (4.67.1)
# Requirement already satisfied: typing-extensions<6.0,>=4.4.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from lightning) (4.12.2)
# Requirement already satisfied: pytorch-lightning in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from lightning) (2.5.0.post0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning) (3.11.11)
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from lightning-utilities<2.0,>=0.10.0->lightning) (75.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from packaging<25.0,>=20.0->lightning) (3.2.1)
# Requirement already satisfied: filelock in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from torch<4.0,>=2.1.0->lightning) (3.16.1)
# Requirement already satisfied: sympy in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from torch<4.0,>=2.1.0->lightning) (1.13.3)
# Requirement already satisfied: networkx in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from torch<4.0,>=2.1.0->lightning) (3.4.2)
# Requirement already satisfied: jinja2 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from torch<4.0,>=2.1.0->lightning) (3.1.5)
# Requirement already satisfied: numpy>1.20.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from torchmetrics<3.0,>=0.7.0->lightning) (1.26.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (1.18.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from jinja2->torch<4.0,>=2.1.0->lightning) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from sympy->torch<4.0,>=2.1.0->lightning) (1.3.0)
# Requirement already satisfied: idna>=2.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (3.10)
# Requirement already satisfied: amazon-textract-textractor in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (1.8.5)
# Requirement already satisfied: Pillow in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from amazon-textract-textractor) (11.1.0)
# Requirement already satisfied: XlsxWriter<4,>=3.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from amazon-textract-textractor) (3.2.1)
# Requirement already satisfied: amazon-textract-caller<1,>=0.2.4 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from amazon-textract-textractor) (0.2.4)
# Requirement already satisfied: editdistance<0.9,>=0.6.2 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from amazon-textract-textractor) (0.8.1)
# Requirement already satisfied: tabulate<0.10,>=0.9 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from amazon-textract-textractor) (0.9.0)
# Requirement already satisfied: boto3>=1.26.35 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from amazon-textract-caller<1,>=0.2.4->amazon-textract-textractor) (1.36.3)
# Requirement already satisfied: botocore in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from amazon-textract-caller<1,>=0.2.4->amazon-textract-textractor) (1.36.3)
# Requirement already satisfied: amazon-textract-response-parser>=0.1.39 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from amazon-textract-caller<1,>=0.2.4->amazon-textract-textractor) (1.0.3)
# Requirement already satisfied: marshmallow<4,>=3.14 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from amazon-textract-response-parser>=0.1.39->amazon-textract-caller<1,>=0.2.4->amazon-textract-textractor) (3.26.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from boto3>=1.26.35->amazon-textract-caller<1,>=0.2.4->amazon-textract-textractor) (1.0.1)
# Requirement already satisfied: s3transfer<0.12.0,>=0.11.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from boto3>=1.26.35->amazon-textract-caller<1,>=0.2.4->amazon-textract-textractor) (0.11.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from botocore->amazon-textract-caller<1,>=0.2.4->amazon-textract-textractor) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from botocore->amazon-textract-caller<1,>=0.2.4->amazon-textract-textractor) (2.3.0)
# Requirement already satisfied: packaging>=17.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from marshmallow<4,>=3.14->amazon-textract-response-parser>=0.1.39->amazon-textract-caller<1,>=0.2.4->amazon-textract-textractor) (21.3)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.1->botocore->amazon-textract-caller<1,>=0.2.4->amazon-textract-textractor) (1.17.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from packaging>=17.0->marshmallow<4,>=3.14->amazon-textract-response-parser>=0.1.39->amazon-textract-caller<1,>=0.2.4->amazon-textract-textractor) (3.2.1)

# %%
processor = AutoProcessor.from_pretrained(
    "nielsr/udop-large", apply_ocr=False
)

# %%
trainer = pl.Trainer(
    accelerator="gpu",
    logger=True
)
# Out:
# Trainer will use only 1 of 4 GPUs because it is running inside an interactive / notebook environment. You may try to set `Trainer(devices=4)` but please note that multi-GPU inside interactive / notebook environments is considered experimental and unstable. Your mileage may vary.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs

# %%
val_dl = DataLoader(
    ClassificationDataset(processor, './rvl_cdip_jordyvl', split="validation"),
    batch_size=1, num_workers=4, shuffle=False, collate_fn=lambda x: x[0]
)

# %%
model = UDOPModel()
# Out:
# Some weights of the model checkpoint at nielsr/udop-test were not used when initializing UdopForConditionalGeneration: ['encoder.cell2dembedding.x_position_embeddings.weight', 'encoder.cell2dembedding.y_position_embeddings.weight']
# - This IS expected if you are initializing UdopForConditionalGeneration from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing UdopForConditionalGeneration from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of UdopForConditionalGeneration were not initialized from the model checkpoint at nielsr/udop-test and are newly initialized: ['encoder.cell_2d_embedding.x_position_embeddings.weight', 'encoder.cell_2d_embedding.y_position_embeddings.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
predictions = trainer.predict(model, dataloaders=val_dl)
# Out:
# You are using a CUDA device ('NVIDIA A10G') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Predicting: |          | 0/? [00:00<?, ?it/s]
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:724: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1711403380909/work/torch/csrc/utils/tensor_new.cpp:275.)
#   return torch.tensor(value)
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:724: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1711403380909/work/torch/csrc/utils/tensor_new.cpp:275.)
#   return torch.tensor(value)
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:724: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1711403380909/work/torch/csrc/utils/tensor_new.cpp:275.)
#   return torch.tensor(value)
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:724: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1711403380909/work/torch/csrc/utils/tensor_new.cpp:275.)
#   return torch.tensor(value)

# %%
mapping = {
  0: "letter",
  1: "form",
  2: "email",
  3: "handwritten",
  4: "advertisement",
  5: "scientific report",
  6: "scientific publication",
  7: "specification",
  8: "file folder",
  9: "news article",
  10: "budget",
  11: "invoice",
  12: "presentation",
  13: "questionnaire",
  14: "resume",
  15: "memo"
}

targets = [mapping[dt['label']] for dt in load_dataset("jordyvl/rvl_cdip_100_examples_per_class", split='test')]

# %%
report = classification_report(predictions, targets, output_dict=True)
# Out:
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
report
# Out:
# {'': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 1.0},
#  '+': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 1.0},
#  'Documentwritten': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'Public': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 1.0},
#  'The': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 1.0},
#  'advertisement': {'precision': 0.52,
#   'recall': 1.0,
#   'f1-score': 0.6842105263157895,
#   'support': 13.0},
#  'advertisement folder': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'budget': {'precision': 0.68,
#   'recall': 0.8095238095238095,
#   'f1-score': 0.7391304347826086,
#   'support': 21.0},
#  'budget request': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 3.0},
#  'budgets': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 1.0},
#  'email': {'precision': 0.84,
#   'recall': 0.9130434782608695,
#   'f1-score': 0.875,
#   'support': 23.0},
#  'email address': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 2.0},
#  'email article': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'email email': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 2.0},
#  'file': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 7.0},
#  'file article': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'file folder': {'precision': 0.76,
#   'recall': 1.0,
#   'f1-score': 0.8636363636363636,
#   'support': 19.0},
#  'form': {'precision': 0.84,
#   'recall': 0.65625,
#   'f1-score': 0.7368421052631579,
#   'support': 32.0},
#  'form completed': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'form folder': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 5.0},
#  'form of': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 1.0},
#  'form the': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'formwritten': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 13.0},
#  'formwritten note': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'hand': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 2.0},
#  'handwritten': {'precision': 0.08,
#   'recall': 1.0,
#   'f1-score': 0.14814814814814814,
#   'support': 2.0},
#  'invoice': {'precision': 0.8,
#   'recall': 0.9523809523809523,
#   'f1-score': 0.8695652173913043,
#   'support': 21.0},
#  'letter': {'precision': 0.68,
#   'recall': 0.9444444444444444,
#   'f1-score': 0.7906976744186046,
#   'support': 18.0},
#  'letterwritten': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 2.0},
#  'memo': {'precision': 0.8, 'recall': 0.8, 'f1-score': 0.8, 'support': 25.0},
#  'memo The': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'news': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 3.0},
#  'news appears': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'news article': {'precision': 0.76,
#   'recall': 1.0,
#   'f1-score': 0.8636363636363636,
#   'support': 19.0},
#  'news publication': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'presentation': {'precision': 0.52,
#   'recall': 0.8666666666666667,
#   'f1-score': 0.65,
#   'support': 15.0},
#  'presentation article': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'presentationwritten': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'questionnaire': {'precision': 0.52,
#   'recall': 1.0,
#   'f1-score': 0.6842105263157895,
#   'support': 13.0},
#  'questionnaire about': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'questionnairewritten': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'resume': {'precision': 0.36,
#   'recall': 1.0,
#   'f1-score': 0.5294117647058824,
#   'support': 9.0},
#  'resume resume': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 2.0},
#  'scientific': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 23.0},
#  'scientific article': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 2.0},
#  'scientific for': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'scientific on': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'scientific publication': {'precision': 0.96,
#   'recall': 0.8571428571428571,
#   'f1-score': 0.9056603773584906,
#   'support': 28.0},
#  'scientific report': {'precision': 0.72,
#   'recall': 1.0,
#   'f1-score': 0.8372093023255814,
#   'support': 18.0},
#  'scientific report issued': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 2.0},
#  'scientific scientific': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'scientific the': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'scientificwritten': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 4.0},
#  'specification': {'precision': 0.6,
#   'recall': 0.8823529411764706,
#   'f1-score': 0.7142857142857143,
#   'support': 17.0},
#  'specification effective': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 6.0},
#  'specification report': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'the': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 2.0},
#  'the article': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'www': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 1.0},
#  'accuracy': 0.6525,
#  'macro avg': {'precision': 0.1769491525423729,
#   'recall': 0.2488441550778995,
#   'f1-score': 0.19816346641667454,
#   'support': 400.0},
#  'weighted avg': {'precision': 0.5329,
#   'recall': 0.6525,
#   'f1-score': 0.5742722175885127,
#   'support': 400.0}}

# %%
# model_tar_path = "./model/model.tar.gz"

# extract_dir = "./model/extracted_model"
# os.makedirs(extract_dir, exist_ok=True)

# with tarfile.open(model_tar_path, "r:gz") as tar:
#     tar.extractall(path=extract_dir)

# %%
model = UDOPModel.load_from_checkpoint("./model/extracted_model/best_model.ckpt")
# Out:
# Some weights of the model checkpoint at nielsr/udop-test were not used when initializing UdopForConditionalGeneration: ['encoder.cell2dembedding.x_position_embeddings.weight', 'encoder.cell2dembedding.y_position_embeddings.weight']
# - This IS expected if you are initializing UdopForConditionalGeneration from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing UdopForConditionalGeneration from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of UdopForConditionalGeneration were not initialized from the model checkpoint at nielsr/udop-test and are newly initialized: ['encoder.cell_2d_embedding.x_position_embeddings.weight', 'encoder.cell_2d_embedding.y_position_embeddings.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
ftpredictions = trainer.predict(model, dataloaders=val_dl)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Predicting: |          | 0/? [00:00<?, ?it/s]
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:724: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1711403380909/work/torch/csrc/utils/tensor_new.cpp:275.)
#   return torch.tensor(value)
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:724: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1711403380909/work/torch/csrc/utils/tensor_new.cpp:275.)
#   return torch.tensor(value)
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:724: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1711403380909/work/torch/csrc/utils/tensor_new.cpp:275.)
#   return torch.tensor(value)
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:724: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1711403380909/work/torch/csrc/utils/tensor_new.cpp:275.)
#   return torch.tensor(value)

# %%
ftreport = classification_report(ftpredictions, targets, output_dict=True)
# Out:
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
ftreport
# Out:
# {'': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 1.0},
#  'Documentwritten': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'advertisement': {'precision': 0.6,
#   'recall': 1.0,
#   'f1-score': 0.75,
#   'support': 15.0},
#  'advertisement folder': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'budget': {'precision': 0.72,
#   'recall': 0.8571428571428571,
#   'f1-score': 0.782608695652174,
#   'support': 21.0},
#  'budget budget': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'budget request': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 2.0},
#  'email': {'precision': 0.72,
#   'recall': 0.8181818181818182,
#   'f1-score': 0.7659574468085106,
#   'support': 22.0},
#  'email ': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 1.0},
#  'email address': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 3.0},
#  'email article': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'email email': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 2.0},
#  'email folder': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 8.0},
#  'email subject': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'file': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 4.0},
#  'file article': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'file folder': {'precision': 0.48,
#   'recall': 1.0,
#   'f1-score': 0.6486486486486487,
#   'support': 12.0},
#  'form': {'precision': 0.92,
#   'recall': 0.6216216216216216,
#   'f1-score': 0.7419354838709677,
#   'support': 37.0},
#  'form completed': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'form folder': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 4.0},
#  'form on': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 1.0},
#  'formwritten': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 4.0},
#  'formwritten form': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'hand': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 1.0},
#  'handwritten': {'precision': 0.44,
#   'recall': 1.0,
#   'f1-score': 0.6111111111111112,
#   'support': 11.0},
#  'handwritten form': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'invoice': {'precision': 0.8,
#   'recall': 0.9523809523809523,
#   'f1-score': 0.8695652173913043,
#   'support': 21.0},
#  'invoice invoice': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 2.0},
#  'letter': {'precision': 0.72,
#   'recall': 0.9,
#   'f1-score': 0.8,
#   'support': 20.0},
#  'letter letter': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'letterwritten': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 2.0},
#  'memo': {'precision': 0.76,
#   'recall': 0.8636363636363636,
#   'f1-score': 0.8085106382978723,
#   'support': 22.0},
#  'memo from': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'news': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 4.0},
#  'news appears': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'news article': {'precision': 0.88,
#   'recall': 1.0,
#   'f1-score': 0.9361702127659575,
#   'support': 22.0},
#  'news publication': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 2.0},
#  'presentation': {'precision': 0.44,
#   'recall': 1.0,
#   'f1-score': 0.6111111111111112,
#   'support': 11.0},
#  'press': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 1.0},
#  'questionnaire': {'precision': 0.56,
#   'recall': 1.0,
#   'f1-score': 0.717948717948718,
#   'support': 14.0},
#  'questionnaire about': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'resume': {'precision': 0.64,
#   'recall': 1.0,
#   'f1-score': 0.7804878048780488,
#   'support': 16.0},
#  'resume resume': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 4.0},
#  'scientific': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 17.0},
#  'scientific article': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'scientific form': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'scientific publication': {'precision': 0.92,
#   'recall': 0.92,
#   'f1-score': 0.92,
#   'support': 25.0},
#  'scientific report': {'precision': 0.8,
#   'recall': 1.0,
#   'f1-score': 0.8888888888888888,
#   'support': 20.0},
#  'scientific report is': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'scientific report prepared': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'scientifice': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'scientificwritten': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 4.0},
#  'specification': {'precision': 0.6,
#   'recall': 0.8823529411764706,
#   'f1-score': 0.7142857142857143,
#   'support': 17.0},
#  'specification effective': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 5.0},
#  'specification report': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'specification super': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'specificationwritten': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'www': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 1.0},
#  'accuracy': 0.6875,
#  'macro avg': {'precision': 0.1896551724137931,
#   'recall': 0.25543649231276006,
#   'f1-score': 0.2128832705458453,
#   'support': 400.0},
#  'weighted avg': {'precision': 0.56,
#   'recall': 0.6875,
#   'f1-score': 0.6032981442713108,
#   'support': 400.0}}
