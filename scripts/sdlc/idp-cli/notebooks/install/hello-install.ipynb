# %%
# %load_ext autoreload
# %autoreload 2

import json
from IPython.display import Markdown, JSON
from dotenv import load_dotenv

from loguru import logger

load_dotenv()
# Out:
# True

# %%
from idp_cli.service.install_service import InstallService


stack_name="idp-Stack"
account_id="715841340161"
# bucket_name="idp-dev-stack-715841340161-us-east-1"

service = InstallService(account_id=account_id, cwd="../../../../", debug=True)

service.publish()
# Out:
# 2025-02-26 15:09:50.072 | DEBUG    | idp_cli.service.install_service:__init__:33 - Using working directory: /Users/vincilb/Documents/Code/GENAIIC/candidate-genaiic-reusable-assets/genaiic-idp-accelerator
# 2025-02-26 15:09:50.384 | INFO     | idp_cli.service.install_service:check_docker_availability:77 - Docker is available and running
# 2025-02-26 15:09:50.385 | DEBUG    | idp_cli.service.install_service:check_docker_availability:78 - Docker info: Client:
#  Version:    27.3.1
#  Context:    default
#  Debug Mode: false
#  Plugins:
#   buildx: Docker Buildx (Docker Inc.)
#     Version:  v0.17.1-desktop.1
#     Path:     /Users/vincilb/.docker/cli-plugins/docker-buildx
#   compose: Docker Compose (Docker Inc.)
#     Version:  v2.29.7-desktop.1
#     Path:     /Users/vincilb/.docker/cli-plugins/docker-compose
#   debug: Get a shell into any image or container (Docker Inc.)
#     Version:  0.0.37
#     Path:     /Users/vincilb/.docker/cli-plugins/docker-debug
# ...

# %%
service.install(admin_email="vincilb@amazon.com", idp_pattern="Pattern2 - Packet processing with Textract and Bedrock")
# Out:
# 2025-02-26 15:27:19.036 | DEBUG    | idp_cli.service.install_service:install:169 - Running CloudFormation deploy command: aws cloudformation deploy --region us-east-1 --template-file .aws-sam/idp-main.yaml --s3-bucket idp-715841340161-us-east-1 --s3-prefix idp/0.2.2 --capabilities CAPABILITY_NAMED_IAM CAPABILITY_AUTO_EXPAND --parameter-overrides IDPPattern=Pattern2 - Packet processing with Textract and Bedrock AdminEmail=vincilb@amazon.com --stack-name idp-Stack
# 2025-02-26 15:40:48.693 | DEBUG    | idp_cli.service.install_service:install:186 - CloudFormation deploy stdout:
# Waiting for changeset to be created..
# Waiting for stack create/update to complete
# Successfully created/updated stack - idp-Stack
#
# 2025-02-26 15:40:48.693 | DEBUG    | idp_cli.service.install_service:install:188 - CloudFormation deploy stderr:
# Uploading to idp/0.2.2/04ab3fb195e8a48d5b29e7a3a7e294d7.template  118058 / 118058.0  (100.00%)
# ...
